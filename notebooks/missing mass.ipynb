# %%
import ROOT
import math
from array import array
import numpy as np
# Out:
# Welcome to JupyROOT 6.26/00

# %%
ls -l *.root
# Out:
# -rw-r--r--  1 akhanal  staff       44490 Feb 13  2022 basic.root
# -rw-r--r--  1 akhanal  staff      890817 Feb 22  2022 data_all_fde.root
# -rw-r--r--  1 akhanal  staff     7487446 Feb 22  2022 data_all_fte.root
# -rw-r--r--  1 akhanal  staff     7391613 Feb 22  2022 data_all_fte_ecornonly.root
# -rw-r--r--  1 akhanal  staff     7233824 Feb 22  2022 data_all_fte_nocorn.root
# -rw-r--r--  1 akhanal  staff      243193 Feb 21  2022 data_fall2018_in_fde.root
# -rw-r--r--  1 akhanal  staff      256433 Jun 16 22:29 data_fall2018_in_fde_goodruns.root
# -rw-r--r--  1 akhanal  staff      273170 Jul 28 18:57 data_fall2018_in_fde_goodruns_hasLamSigWeight.root
# -rw-r--r--  1 akhanal  staff   511797782 Oct  4 12:13 data_fall2018_in_fde_goodruns_mixEv_ekm_fkp_skp.root
# -rw-r--r--  1 akhanal  staff   202574473 Jul 28 16:37 data_fall2018_in_fde_goodruns_threeKaon_mixEv_bg.root
# -rw-r--r--  1 akhanal  staff     3130991 Feb 22  2022 data_fall2018_in_fte.root
# ...

# %%
df = ROOT.RDataFrame("T", "data_xi1320_2kplus_fall2018_out_fde.root")
print(f"Columns in the dataset: {df.GetColumnNames()}")
# Out:
# Columns in the dataset: { "W", "beam_e", "e_e", "e_p", "e_phi", "e_px", "e_py", "e_pz", "e_theta", "e_vx", "e_vy", "e_vz", "evnum", "fkp_e", "fkp_p", "fkp_phi", "fkp_px", "fkp_py", "fkp_pz", "fkp_theta", "fkp_vx", "fkp_vy", "fkp_vz", "m_fkpskp", "mm_e", "mm_fkp", "mm_fkpskp", "mm_skp", "nu", "q2", "runnum", "skp_e", "skp_p", "skp_phi", "skp_px", "skp_py", "skp_pz", "skp_theta", "skp_vx", "skp_vy", "skp_vz", "x" }

# %% [markdown]
# **two Kaon MIssing Mass**

# %%
h = ROOT.RDataFrame("T","data_xi1320_2kplus_fall2018_out_fde.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_xi1320_2kplus_fall2018_in_fde.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_xi1320_2kplus_spring2019_in_fde.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_xi1320_2kplus_rgk_7546MeV_out_fde.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_xi1320_2kplus_rgk_6535MeV_out_fde.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")

#100, 1.2, 1.7#250, 0.5, 3.0
#h.SetTitle("MM(eK^{+}K^{+})")
h.SetTitle("")
#h.SetTitleSize(0.06, "x")
h.GetXaxis().SetTitle("MM(eK^{+}K^{+}) [GeV/c^{2}]")
h.GetYaxis().SetTitle("Counts/10 MeV/c^{2}")
h.GetXaxis().SetTitleSize(0.05)
h.GetYaxis().SetTitleSize(0.05)
h.GetXaxis().SetTitleOffset(0.9)
#h.GetYaxis().SetTitleOffset(0.9)
#fn = ROOT.TF1("fn", ROOT.Voigt, 1.0, 2.5, 3)#median, sigma, lg
#fn.SetParameters(1.3, 0.004, 0.001)

# %jsroot on
ROOT.gStyle.SetOptStat(0000)
ROOT.gStyle.SetOptFit(0000)
c = ROOT.TCanvas()
#h.Draw()
h.Draw("E")
h.SetLineColor(ROOT.kRed)
h.SetFillColor(ROOT.kGreen)
h.SetMarkerStyle(21)
h.SetMarkerSize(0.8)

l=ROOT.TLine(1.322, 0, 1.322, 250)
l.SetLineColor(1)
l.SetLineStyle(10)
l.Draw("same")
l2=ROOT.TLine(1.532, 0, 1.532, 250)
l2.SetLineColor(1)
l2.SetLineStyle(10)
l2.Draw("same")


legend1 = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
legend1.SetHeader("fall2018-out-fde","C") # option "C" allows to center the header
#legend1.SetHeader("fall2018-in-fde","C")
#legend1.SetHeader("spring2019-in-fde","C")
#legend1.SetHeader("rgk-7546MeV-out-fde","C")
#legend1.SetHeader("rgk-6535MeV-out-fde","C")
#legend1.AddEntry("mc","mc","f")
#legend1.AddEntry("data","data-fall2018-out-fde","lpe")
#legend1.AddEntry("data","data-fall2018-in-fde","lpe")
#legend1.AddEntry("data","data-spring2019-in-fde","lpe")
legend1.SetTextFont(72)
legend1.SetTextSize(0.8)
legend1.Draw()

c.Draw()
# Out:
# <div id="root_plot_1664933584113"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664933584113(Core) {
# ...

# %% [markdown]
# **two Kaon MIssing Mass FTe**

# %%
#h = ROOT.RDataFrame("T","data_xi1320_2kplus_fall2018_out_fte.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_xi1320_2kplus_fall2018_in_fte.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_xi1320_2kplus_spring2019_in_fte.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
h = ROOT.RDataFrame("T","data_xi1320_2kplus_rgk_out_fte.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")
#100, 1.2, 1.7#250, 0.5, 3.0
#h.SetTitle("MM(eK^{+}K^{+})")

#MC
#h = ROOT.RDataFrame("T","../simu_prod/xi_1820_bw_mc_fall2018out_fte/plot/rec_xi_1820_bw_mc_fall2018out_fte.root").Histo1D(("data", "data", 250, 0.5, 3.0), "mm_fkpskp")

h.SetTitle(" ")
#h.SetTitleSize(0.06, "x")
h.GetXaxis().SetTitle("MM(eK^{+}K^{+}) [GeV/c^{2}]")
h.GetYaxis().SetTitle("Counts/10 MeV/c^{2}")
h.GetXaxis().SetTitleSize(0.05)
h.GetYaxis().SetTitleSize(0.05)
h.GetXaxis().SetTitleOffset(0.9)
#h.GetYaxis().SetTitleOffset(0.9)
#fn = ROOT.TF1("fn", ROOT.Voigt, 1.0, 2.5, 3)#median, sigma, lg
#fn.SetParameters(1.3, 0.004, 0.001)

# %jsroot on
ROOT.gStyle.SetOptStat(0000)
ROOT.gStyle.SetOptFit(0000)
c = ROOT.TCanvas()
#h.Draw("")
h.Draw("E")
h.SetLineColor(ROOT.kRed)
h.SetFillColor(ROOT.kGreen)
h.SetMarkerStyle(21)
h.SetMarkerSize(0.8)

l=ROOT.TLine(1.322, 0, 1.322, 180)
l.SetLineColor(1)
l.SetLineStyle(10)
l.Draw("same")
l2=ROOT.TLine(1.532, 0, 1.532, 180)
l2.SetLineColor(1)
l2.SetLineStyle(10)
l2.Draw("same")


legend1 = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
#legend1.SetHeader("fall2018-out-fte","C") # option "C" allows to center the header
#legend1.SetHeader("fall2018-in-fte","C")
#legend1.SetHeader("spring2019-in-fte","C")
legend1.SetHeader("rgk-7546MeV-out-fte","C")
#legend1.AddEntry("mc","mc","f")
#legend1.AddEntry("data","data-fall2018-out-fte","lpe")#lpe
#legend1.AddEntry("data","data-fall2018-in-fte","lpe")#lpe
#legend1.AddEntry("data","data-spring2019-in-fte","lpe")#lpe
legend1.SetTextFont(72)
legend1.SetTextSize(0.8)
legend1.Draw()

c.Draw()
# Out:
# <div id="root_plot_1664843754421"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664843754421(Core) {
# ...

# %% [markdown]
# **three Kaon Missing Mass FDe**

# %%
#h = ROOT.RDataFrame("T","data_fall2018_out_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")
#h = ROOT.RDataFrame("T","data_fall2018_in_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")
h = ROOT.RDataFrame("T","data_spring2019_in_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")


htest1 = ROOT.RDataFrame("T","data_spring2019_in_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpaspipskpkm")#check#mm_fkpaspipskpkm
htest2 = ROOT.RDataFrame("T","data_spring2019_in_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpaspipkm")
htest3 = ROOT.RDataFrame("T","data_spring2019_in_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkmaspim")
htest4 = ROOT.RDataFrame("T","data_spring2019_in_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpaspipskpaspipkmaspim")
#100, 1.2, 1.7#250, 0.5, 3.0
#MC
#h = ROOT.RDataFrame("T","../simu_prod/xi_1820_bw_mc_fall2018out_fde/plot/rec_xi_1820_bw_mc_fall2018out_fde.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")

#h.SetTitle("MM(eK^{+}K^{+})")
h.SetTitle("")
#h.SetTitleSize(0.06, "x")
h.GetXaxis().SetTitle("MM(eK^{+}K^{+}K^{-}) [GeV/c^{2}]")
h.GetYaxis().SetTitle("Counts/24 MeV/c^{2}")
h.GetXaxis().SetTitleSize(0.05)
h.GetYaxis().SetTitleSize(0.05)
h.GetXaxis().SetTitleOffset(0.9)
#h.GetYaxis().SetTitleOffset(0.9)
#fn = ROOT.TF1("fn", ROOT.Voigt, 1.0, 2.5, 3)#median, sigma, lg
#fn.SetParameters(1.3, 0.004, 0.001)

# %jsroot on
ROOT.gStyle.SetOptStat(0000)
ROOT.gStyle.SetOptFit(0000)
c = ROOT.TCanvas()
#h.Draw()
h.Draw("E")
htest1.Draw("same")
#htest2.Draw("same")
#htest3.Draw("same")
#htest4.Draw("same")

h.SetLineColor(ROOT.kRed)
h.SetFillColor(ROOT.kGreen)
h.SetMarkerStyle(21)
h.SetMarkerSize(0.8)


legend1 = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
#legend1.SetHeader("fall2018-out-fde","C") # option "C" allows to center the header
#legend1.SetHeader("fall2018-in-fde","C")
legend1.SetHeader("spring2019-in-fde","C")
#legend1.AddEntry("mc","mc","f")
#legend1.AddEntry("data","data-fall2018-out-fde","lpe")
#legend1.AddEntry("data","data-fall2018-in-fde","lpe")
#legend1.AddEntry("data","data-spring2019-in-fde","lpe")
legend1.SetTextFont(72)
legend1.SetTextSize(0.8)
legend1.Draw()

c.Draw()
# Out:
# <div id="root_plot_1664935402379"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664935402379(Core) {
# ...

# %% [markdown]
# **three Kaon Missing Mass FTe**

# %%
h = ROOT.RDataFrame("T","data_fall2018_out_fte.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")
#h = ROOT.RDataFrame("T","data_fall2018_in_fte.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")
#h = ROOT.RDataFrame("T","data_spring2019_in_fte.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")
#100, 1.2, 1.7#250, 0.5, 3.0
#h.SetTitle("MM(eK^{+}K^{+})")
#MC
#h = ROOT.RDataFrame("T","../simu_prod/xi_1820_bw_mc_fall2018out_fte/plot/rec_xi_1820_bw_mc_fall2018out_fte.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpkm")

#htest = ROOT.RDataFrame("T","data_fall2018_out_fte.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpaspipskpkm")#check#mm_fkpaspipskpkm
#htest = ROOT.RDataFrame("T","data_fall2018_out_fte.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpskpaspipkm")
htest = ROOT.RDataFrame("T","data_fall2018_out_fte.root").Histo1D(("data", "data", 100, 0.0, 2.4), "mm_fkpaspipskpaspipkmaspim")

h.SetTitle("")
#h.SetTitleSize(0.06, "x")
h.GetXaxis().SetTitle("MM(eK^{+}K^{+}K^{-}) [GeV/c^{2}]")
h.GetYaxis().SetTitle("Counts/24 MeV/c^{2}")
h.GetXaxis().SetTitleSize(0.05)
h.GetYaxis().SetTitleSize(0.05)
h.GetXaxis().SetTitleOffset(0.9)
#h.GetYaxis().SetTitleOffset(0.9)
#fn = ROOT.TF1("fn", ROOT.Voigt, 1.0, 2.5, 3)#median, sigma, lg
#fn.SetParameters(1.3, 0.004, 0.001)

# %jsroot on
ROOT.gStyle.SetOptStat(111)
ROOT.gStyle.SetOptFit(0000)
c = ROOT.TCanvas()
#h.Draw()
h.Draw("E")
htest.Draw("same")
h.SetLineColor(ROOT.kRed)
h.SetFillColor(ROOT.kGreen)
h.SetMarkerStyle(21)
h.SetMarkerSize(0.8)


legend1 = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
legend1.SetHeader("fall2018-out-fte","C") # option "C" allows to center the header
#legend1.SetHeader("fall2018-in-fte","C")
#legend1.SetHeader("spring2019-in-fte","C")
#legend1.AddEntry("mc","mc","f")
#legend1.AddEntry("data","data-fall2018-out-fte","lpe")
#legend1.AddEntry("data","data-fall2018-in-fte","lpe")
#legend1.AddEntry("data","data-spring2019-in-fte","lpe")
legend1.SetTextFont(72)
legend1.SetTextSize(0.8)
legend1.Draw()

c.Draw()
# Out:
# <div id="root_plot_1664847790203"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664847790203(Core) {
# ...

# %% [markdown]
# **MM Scatter PLots - FTe**

# %%
#h = ROOT.RDataFrame("T","data_fall2018_out_fte.root").Histo2D(("hxy", "hxy", 25, 0.9, 1.4, 25, 1.5, 2.5), "mm_fkpskpkm", "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_fall2018_in_fte.root").Histo2D(("hxy", "hxy", 25, 0.9, 1.4, 25, 1.5, 2.5), "mm_fkpskpkm", "mm_fkpskp")
h = ROOT.RDataFrame("T","data_spring2019_in_fte.root").Histo2D(("hxy", "hxy", 25, 0.9, 1.4, 25, 1.5, 2.5), "mm_fkpskpkm", "mm_fkpskp")
#100, 1.2, 1.7#250, 0.5, 3.0
#h.SetTitle("MM(eK^{+}K^{+})")
h.SetTitle("")
#h.SetTitleSize(0.06, "x")
h.GetXaxis().SetTitle("MM(eK^{+}K^{+}K^{-}) [GeV/c^{2}]")
h.GetYaxis().SetTitle("MM(eK^{+}K^{+})[GeV/c^{2}]")
h.GetXaxis().SetTitleSize(0.05)
h.GetYaxis().SetTitleSize(0.05)
h.GetXaxis().SetTitleOffset(0.9)
h.GetYaxis().SetTitleOffset(0.9)

# %jsroot on
ROOT.gStyle.SetOptStat(0000)
ROOT.gStyle.SetOptFit(0000)
c = ROOT.TCanvas()
h.Draw("colz")#colz#lego
h.SetLineColor(ROOT.kRed)
h.SetFillColor(ROOT.kGreen)
h.SetMarkerStyle(21)
h.SetMarkerSize(0.8)
legend1 = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
#legend1.SetHeader("fall2018-out-fte","C") # option "C" allows to center the header
#legend1.SetHeader("fall2018-in-fte","C")
legend1.SetHeader("spring2019-in-fte","C")
#legend1.AddEntry("mc","mc","f")
#legend1.AddEntry("data","data-fall2018-out-fte","lpe")
#legend1.AddEntry("data","data-fall2018-in-fte","lpe")
#legend1.AddEntry("data","data-spring2019-in-fte","lpe")
legend1.SetTextFont(72)
legend1.SetTextSize(0.8)
legend1.Draw()

c.Draw()
# Out:
# <div id="root_plot_1653598168191"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1653598168191(Core) {
# ...

# %% [markdown]
# **MM Scatter PLots - FDe**

# %%
h = ROOT.RDataFrame("T","data_fall2018_out_fde.root").Histo2D(("hxy", "hxy", 25, 0.9, 1.4, 25, 1.5, 2.5), "mm_fkpskpkm", "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_fall2018_in_fde.root").Histo2D(("hxy", "hxy", 25, 0.9, 1.4, 25, 1.5, 2.5), "mm_fkpskpkm", "mm_fkpskp")
#h = ROOT.RDataFrame("T","data_spring2019_in_fde.root").Histo2D(("hxy", "hxy", 25, 0.9, 1.4, 25, 1.5, 2.5), "mm_fkpskpkm", "mm_fkpskp")
#100, 1.2, 1.7#250, 0.5, 3.0
#h.SetTitle("MM(eK^{+}K^{+})")
h.SetTitle("")
#h.SetTitleSize(0.06, "x")
h.GetXaxis().SetTitle("MM(eK^{+}K^{+}K^{-}) [GeV/c^{2}]")
h.GetYaxis().SetTitle("MM(eK^{+}K^{+})[GeV/c^{2}]")
h.GetXaxis().SetTitleSize(0.05)
h.GetYaxis().SetTitleSize(0.05)
h.GetXaxis().SetTitleOffset(0.9)
h.GetYaxis().SetTitleOffset(0.9)

# %jsroot on
ROOT.gStyle.SetOptStat(0000)
ROOT.gStyle.SetOptFit(0000)
c = ROOT.TCanvas()
h.Draw("colz")#colz#lego
h.SetLineColor(ROOT.kRed)
h.SetFillColor(ROOT.kGreen)
h.SetMarkerStyle(21)
h.SetMarkerSize(0.8)
legend1 = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
legend1.SetHeader("fall2018-out-fde","C") # option "C" allows to center the header
#legend1.SetHeader("fall2018-in-fde","C")
#legend1.SetHeader("spring2019-in-fde","C")
#legend1.AddEntry("mc","mc","f")
#legend1.AddEntry("data","data-fall2018-out-fte","lpe")
#legend1.AddEntry("data","data-fall2018-in-fte","lpe")
#legend1.AddEntry("data","data-spring2019-in-fte","lpe")
legend1.SetTextFont(72)
legend1.SetTextSize(0.8)
legend1.Draw()

c.Draw()
# Out:
# <div id="root_plot_1653598340156"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1653598340156(Core) {
# ...

# %%
import ROOT
import math
from array import array
import numpy as np
# Out:
# Welcome to JupyROOT 6.26/00

# %%
data_tree = "T"
gen_mctree = "T"
rec_mctree = "T"
data_file = "data_fall2018_out_fte.root"
gen_mcfile = "mc_gen_fall2018_out_fte.root"
rec_mcfile = "mc_rec_fall2018_out_fte.root"
#df = ROOT.RDataFrame(data_tree, data_file)
df = ROOT.RDataFrame("T", "data_fall2018_out_fte_goodruns_hasLamSigWeight1.root")
genmcdf = ROOT.RDataFrame(gen_mctree, gen_mcfile)
recmcdf = ROOT.RDataFrame(rec_mctree, rec_mcfile)
print(f"Columns in the dataset: {df.GetColumnNames()}")
#print(f"Columns in the dataset: {genmcdf.GetColumnNames()}")
#print(f"Columns in the dataset: {recmcdf.GetColumnNames()}")
#print(f"Columns in the dataset: {ROOT.RDataFrame("T", "data_xi1320_2kplus_fall2018_out_fde.root").GetColumnNames()}")
# Out:
# Columns in the dataset: { "W", "beam_e", "e_e", "e_p", "e_phi", "e_px", "e_py", "e_pz", "e_theta", "e_vx", "e_vy", "e_vz", "evnum", "fkp_e", "fkp_p", "fkp_phi", "fkp_px", "fkp_py", "fkp_pz", "fkp_theta", "fkp_vx", "fkp_vy", "fkp_vz", "km_e", "km_p", "km_phi", "km_px", "km_py", "km_pz", "km_theta", "km_vx", "km_vy", "km_vz", "m_fkpkm", "m_fkpskp", "m_fkpskpkm", "m_skpkm", "mm_e", "mm_fkp", "mm_fkpaspipskpaspipkm", "mm_fkpaspipskpaspipkmaspim", "mm_fkpaspipskpkm", "mm_fkpaspipskpkmaspim", "mm_fkpkm", "mm_fkpskp", "mm_fkpskpaspipkm", "mm_fkpskpaspipkmaspim", "mm_fkpskpkm", "mm_fkpskpkmaspim", "mm_km", "mm_skp", "mm_skpkm", "nu", "q2", "runnum", "skp_e", "skp_p", "skp_phi", "skp_px", "skp_py", "skp_pz", "skp_theta", "skp_vx", "skp_vy", "skp_vz", "w_bg", "w_lam", "w_lamsig", "w_sig", "x" }

# %%
#h1 = ROOT.RDataFrame("T","mc_gen_fall2018_out_fde.root").Histo1D(("mc-gen", "mc-gen", 100, 1.5, 3.5), "mm_fkpskp")
#h2 = ROOT.RDataFrame("T","mc_rec_fall2018_out_fde.root").Histo1D(("mc-rec", "mc-rec", 100, 1.5, 3.5), "mm_fkpskp")#50, 1.4, 2.4
h1 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.66<=mm_fkpskp && mm_fkpskp<=2.26 && e_e>=1.0 && e_theta <=35 && 5<=e_theta").Histo1D(("mc-gen", "mc-gen", 25, 1.5, 2.5), "mm_fkpskp")
h2 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25 && e_e>=1.0 && e_theta <=35 && 5<=e_theta").Histo1D(("mc-rec", "mc-rec", 25, 1.5, 2.5), "mm_fkpskp")
#h3 = ROOT.RDataFrame("T","data_fall2018_out_fte.root").Histo1D(("data", "data", 50, 1.5, 3.5), "mm_fkpskp")
#100, 1.5, 3.5 #50, 1.5, 3.5#25, 1.4, 2.4#50, 1.4, 2.4
h2.GetXaxis().SetTitle("Mx(ep#rightarroweK^{+}K^{+}X) [GeV/c^{2}]")
h1.GetYaxis().SetTitle("Counts/40 MeV/c^{2}")
#h1.GetXaxis().SetLabelSize(0.05)
#h1.GetYaxis().SetLabelSize(0.05)
h1.GetXaxis().SetTitleSize(0.05)
h1.GetYaxis().SetTitleSize(0.05)
h1.GetXaxis().SetTitleOffset(0.9)
h1.GetYaxis().SetTitleOffset(0.9)

h2.GetXaxis().SetTitle("Mx(ep#rightarroweK^{+}K^{+}X) [GeV/c^{2}]")
h2.GetYaxis().SetTitle("Counts/40 MeV/c^{2}")
#h2.GetXaxis().SetLabelSize(0.05)
#h2.GetYaxis().SetLabelSize(0.05)
h2.GetXaxis().SetTitleSize(0.05)
h2.GetYaxis().SetTitleSize(0.05)
h2.GetXaxis().SetTitleOffset(0.9)
h2.GetYaxis().SetTitleOffset(0.9)


# %jsroot on
c = ROOT.TCanvas()
c.Divide(1,2)
c.cd(1)
ROOT.gStyle.SetOptStat(0)
h2.Draw()
h2.GetYaxis().SetRangeUser(0, 10000000)
#h1.SetTitle("MM(eK^{+}K^{+})")
h1.SetTitle("")
h2.SetTitle("")
h1.SetLineColor(ROOT.kBlue)
#h1.SetFillColor(ROOT.kBlue)
h1.GetXaxis().SetRangeUser(1.55, 2.4)
h1.Draw("SAME")
#h2.Draw()
h2.SetLineColor(ROOT.kRed)
#h2.SetFillColor(ROOT.kRed)
#h3.Draw("SAME")
#h3.SetLineColor(ROOT.kMagenta)#ROOT.kGreen

legend = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
#legend.SetHeader("mc-vs-data-fall2018out-fde","C"); # option "C" allows to center the header
legend.AddEntry("mc-gen","MC-gen","l");
legend.AddEntry("mc-rec","MC-rec","l"); #legend->AddEntry("f1","Function abs(#frac{sin(x)}{x})","l");
#legend.AddEntry("data","data","l"); #legend->AddEntry("gr","Graph with error bars","lep");
legend.Draw();


c.cd(2)
#graph.Draw("P")#AC*#CP#ALP#Psame
#graph.Draw("P")#AC*#CP#ALP#Psame
h1_eff = h2.Clone()
h1_eff.Sumw2()
h1_eff.Divide(h1.GetPtr())
h1_eff.Draw("E")
h1_eff.SetMarkerStyle(21)
h1_eff.SetMarkerSize(0.3)
h1_eff.SetLineColor(ROOT.kRed)
h1_eff.GetXaxis().SetTitleSize(0.05)
h1_eff.GetYaxis().SetTitleSize(0.05)
h1_eff.GetXaxis().SetTitleOffset(0.9)
h1_eff.GetYaxis().SetTitleOffset(0.9)
#h1_eff.GetXaxis().SetRangeUser(1.4, 2.4)
h1_eff.GetYaxis().SetRangeUser(0.001, 0.00035)
h1_eff.SetTitle("#epsilon")
h1_eff.GetXaxis().SetTitle("Mx(ep#rightarroweK^{+}K^{+}X) [GeV/c^{2}]")
h1_eff.GetYaxis().SetTitle("efficiency/(40 MeV/c^{2}) bin")

gr_legend = ROOT.TLegend(0.9,0.8,0.7,0.9)#legend = ROOT.TLegend()
gr_legend.SetHeader("efficiency-fall2018out-fde","C")
gr_legend.Draw()

c.Draw()
# Out:
# <div id="root_plot_1667132407074"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1667132407074(Core) {
# ...

# %% [markdown]
# F18out-FDe

# %%
# %jsroot on
c = ROOT.TCanvas("c", "c", 2400,1600)
ROOT.gStyle.SetOptFit(0)
#colms = math.ceil(math.sqrt(h1_eff.GetNbinsX()))
#rows = math.floor(math.sqrt(h1_eff.GetNbinsX()))
#c.Divide(colms, rows, 1E-11, 1E-11)
c.Divide(4, 4, 1E-11, 1E-11)

for i in range(h1_eff.GetNbinsX()):
    
    bn = i+1
    """
    if bn==1:
        c.cd(1)
        hgen1 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.5<=mm_fkpskp && mm_fkpskp<1.54 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.5,1.54)", "MM[1.5,1.54)", 7, 0.0, 0.14), "q2")
        hrec1 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.5<=mm_fkpskp && mm_fkpskp<1.54 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.5,1.54)", "MM[1.5,1.54)", 7, 0.0, 0.14), "q2") 
        heff1 = hrec1.Clone()
        heff1.Sumw2()
        heff1.Divide(hgen1.GetPtr())
        heff1.SetLineColor(ROOT.kRed)
        heff1.Draw("E")
        hgen1.SetLineColor(ROOT.kMagenta)
        #hgen1.Scale(1/hgen1.Integral())
        hrec1.SetLineColor(ROOT.kBlack)
        #hrec1.Scale(1/hrec1.Integral())
        #hrec1.Draw("same")
        #hgen1.Draw("same")
        #heff1.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==2:
        c.cd(2)
        hgen2 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.54<=mm_fkpskp && mm_fkpskp<1.58 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.54,1.58)", "MM[1.54,1.58)", 7, 0.0, 0.14), "q2")
        hrec2 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.54<=mm_fkpskp && mm_fkpskp<1.58 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.54,1.58)", "MM[1.54,1.58)", 7, 0.0, 0.14), "q2") 
        heff2 = hrec2.Clone()
        heff2.Sumw2()
        heff2.Divide(hgen2.GetPtr())
        heff2.SetLineColor(ROOT.kRed)
        heff2.Draw("E")
        hgen2.SetLineColor(ROOT.kMagenta)
        #hgen2.Scale(1/hgen2.Integral())
        hrec2.SetLineColor(ROOT.kBlack)
        #hrec2.Scale(1/hrec2.Integral())
        #hrec2.Draw("same")
        #hgen2.Draw("same")
        #heff2.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==3:
        c.cd(3)
        hgen3 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.58<=mm_fkpskp && mm_fkpskp<1.62 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.58,1.62)", "MM[1.58,1.62)", 7, 0.0, 0.14), "q2")
        hrec3 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.58<=mm_fkpskp && mm_fkpskp<1.62 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.58,1.62)", "MM[1.58,1.62)", 7, 0.0, 0.14), "q2") 
        heff3 = hrec3.Clone()
        heff3.Sumw2()
        heff3.Divide(hgen3.GetPtr())
        heff3.SetLineColor(ROOT.kRed)
        heff3.Draw("E")
        hgen3.SetLineColor(ROOT.kMagenta)
        #hgen3.Scale(1/hgen3.Integral())
        hrec3.SetLineColor(ROOT.kBlack)
        #hrec3.Scale(1/hrec3.Integral())
        #hrec3.Draw("same")
        #hgen3.Draw("same")
        #heff3.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        hrec3.GetXaxis().SetTitleSize(0.05)
        hrec3.GetYaxis().SetTitleSize(0.05)
        hrec3.GetXaxis().SetTitleOffset(0.9)
        hrec3.GetYaxis().SetTitleOffset(0.9)
        hrec3.GetXaxis().SetTitle("Q^{2} [GeV^{2}/c^{4}]")
        hrec3.GetYaxis().SetTitle("#epsilon/Q^{2} bin")
        continue
    elif bn==4:
        c.cd(4)
        hgen4 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.62<=mm_fkpskp && mm_fkpskp<1.66 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.62,1.66)", "MM[1.62,1.66)", 7, 0.0, 0.14), "q2")
        hrec4 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.62<=mm_fkpskp && mm_fkpskp<1.66 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.62,1.66)", "MM[1.62,1.66)", 7, 0.0, 0.14), "q2") 
        heff4 = hrec4.Clone()
        heff4.Sumw2()
        heff4.Divide(hgen4.GetPtr())
        heff4.SetLineColor(ROOT.kRed)
        heff4.Draw("E")
        hgen4.SetLineColor(ROOT.kMagenta)
        #hgen4.Scale(1/hgen4.Integral())
        hrec4.SetLineColor(ROOT.kBlack)
        #hrec4.Scale(1/hrec4.Integral())
        #hrec4.Draw("same")
        #hgen4.Draw("same")
        #heff4.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==5:###################
        c.cd(5)
        hgen5 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.66<=mm_fkpskp && mm_fkpskp<1.70 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.66,1.70)", "MM[1.66,1.70)", 7, 0.0, 0.14), "q2")
        hrec5 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.66<=mm_fkpskp && mm_fkpskp<1.70 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.66,1.70)", "MM[1.66,1.70)", 7, 0.0, 0.14), "q2") 
        heff5 = hrec5.Clone()
        heff5.Sumw2()
        heff5.Divide(hgen5.GetPtr())
        heff5.SetLineColor(ROOT.kRed)
        heff5.Draw("E")
        hgen5.SetLineColor(ROOT.kMagenta)
        #hgen5.Scale(1/hgen5.Integral())
        hrec5.SetLineColor(ROOT.kBlack)
        #hrec5.Scale(1/hrec5.Integral())
        #hrec5.Draw("same")
        #hgen5.Draw("same")
        #heff5.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==6:
    """
    if bn==6:
        c.cd(1)
        #c.cd(6)
        """
        hgen6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.140), "q2")#25, 0.001, 0.4 #7, 0.0, 0.14 # 5, 0.030, 0.130
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2")
        hrec6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2") 
        """
        hgen6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.70<=mm_fkpskp && mm_fkpskp<1.74 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")#25, 0.001, 0.4 #7, 0.0, 0.14 # 5, 0.030, 0.130#10, 0, 3#25, 0, 5
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2")
        hrec6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.70,1.74) GeV", "MM[1.70,1.74) GeV", 10, 0, 3), "q2") 
        
        heff6 = hrec6.Clone()
        heff6.Sumw2()
        heff6.Divide(hgen6.GetPtr())
        heff6.SetMarkerStyle(21)
        heff6.SetMarkerSize(0.5)
        heff6.SetLineColor(ROOT.kRed)
        heff6.Draw("E")
        heff6.GetXaxis().SetLabelSize(0.05)
        heff6.GetYaxis().SetLabelSize(0.05)
        heff6.GetXaxis().SetTitleSize(0.05)
        heff6.GetYaxis().SetTitleSize(0.05)
        heff6.GetXaxis().SetTitleOffset(0.9)
        heff6.GetYaxis().SetTitleOffset(0.9)
        heff6.GetXaxis().SetTitle("Q^{2} [GeV^{2}/c^{4}]")
        heff6.GetYaxis().SetTitle("#epsilon/Q^{2} bin")
        #hgen6.SetLineColor(ROOT.kMagenta)
        #hgen6.Scale(1/hgen6.Integral())
        #hrec6.SetLineColor(ROOT.kBlack)
        #hrec6.Scale(1/hrec6.Integral())
        #hrec6.Draw("same")
        #hgen6.Draw("same")
        #heff6.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==7:
        #c.cd(7)
        c.cd(2)
        """
        hgen7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2")
        hrec7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2") 
        """
        hgen7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.74<=mm_fkpskp && mm_fkpskp<1.78 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2")
        hrec7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.74,1.78) GeV", "MM[1.74,1.78) GeV", 10, 0, 3), "q2") 
        
        heff7 = hrec7.Clone()
        heff7.Sumw2()
        heff7.Divide(hgen7.GetPtr())
        heff7.SetMarkerStyle(21)
        heff7.SetMarkerSize(0.5)
        heff7.SetLineColor(ROOT.kRed)
        heff7.Draw("E")
        heff7.GetXaxis().SetLabelSize(0.05)
        heff7.GetYaxis().SetLabelSize(0.05)
        #hgen7.SetLineColor(ROOT.kMagenta)
        #hgen7.Scale(1/hgen7.Integral())
        #hrec7.SetLineColor(ROOT.kBlack)
        #hrec7.Scale(1/hrec7.Integral())
        #hrec7.Draw("same")
        #hgen7.Draw("same")
        #heff7.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==8:
        #c.cd(8)
        c.cd(3)
        """
        hgen8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2")
        hrec8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2") 
        """
        hgen8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.78<=mm_fkpskp && mm_fkpskp<1.82  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2")
        hrec8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.78,1.82) GeV", "MM[1.78,1.82) GeV", 10, 0, 3), "q2") 
        
        heff8 = hrec8.Clone()
        heff8.Sumw2()
        heff8.Divide(hgen8.GetPtr())
        heff8.SetMarkerStyle(21)
        heff8.SetMarkerSize(0.5)
        heff8.SetLineColor(ROOT.kRed)
        heff8.Draw("E")
        heff8.GetXaxis().SetLabelSize(0.05)
        heff8.GetYaxis().SetLabelSize(0.05)
        #hgen8.SetLineColor(ROOT.kMagenta)
        #hgen8.Scale(1/hgen8.Integral())
        #hrec8.SetLineColor(ROOT.kBlack)
        #hrec8.Scale(1/hrec8.Integral())
        #hrec8.Draw("same")
        #hgen8.Draw("same")
        #heff8.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==9:
        #c.cd(9)
        c.cd(4)
        """
        hgen9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2")
        hrec9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2") 
        """
        hgen9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.82<=mm_fkpskp && mm_fkpskp<1.86  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2")
        hrec9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.82,1.86) GeV", "MM[1.82,1.86) GeV", 10, 0, 3), "q2") 
        
        heff9 = hrec9.Clone()
        heff9.Sumw2()
        heff9.Divide(hgen9.GetPtr())
        heff9.SetMarkerStyle(21)
        heff9.SetMarkerSize(0.5)
        heff9.SetLineColor(ROOT.kRed)
        heff9.Draw("E")
        heff9.GetXaxis().SetLabelSize(0.05)
        heff9.GetYaxis().SetLabelSize(0.05)
        #hgen9.SetLineColor(ROOT.kMagenta)
        #hgen9.Scale(1/hgen9.Integral())
        #hrec9.SetLineColor(ROOT.kBlack)
        #hrec9.Scale(1/hrec9.Integral())
        #hrec9.Draw("same")
        #hgen9.Draw("same")
        #heff9.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==10:
        #c.cd(10)
        c.cd(5)
        """
        hgen10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2")
        hrec10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2") 
        """
        hgen10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.86<=mm_fkpskp && mm_fkpskp<1.90  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2")
        hrec10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.86,1.90) GeV", "MM[1.86,1.90) GeV", 10, 0, 3), "q2") 
        
        heff10 = hrec10.Clone()
        heff10.Sumw2()
        heff10.Divide(hgen10.GetPtr())
        heff10.SetMarkerStyle(21)
        heff10.SetMarkerSize(0.5)
        heff10.SetLineColor(ROOT.kRed)
        heff10.Draw("E")
        heff10.GetXaxis().SetLabelSize(0.05)
        heff10.GetYaxis().SetLabelSize(0.05)
        #hgen10.SetLineColor(ROOT.kMagenta)
        #hgen10.Scale(1/hgen10.Integral())
        #hrec10.SetLineColor(ROOT.kBlack)
        #hrec10.Scale(1/hrec10.Integral())
        #hrec10.Draw("same")
        #hgen10.Draw("same")
        #heff10.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==11:
        #c.cd(11)
        c.cd(6)
        """
        hgen11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2")
        hrec11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2") 
        """
        hgen11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.90<=mm_fkpskp && mm_fkpskp<1.94  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2")
        hrec11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.90,1.94) GeV", "MM[1.90,1.94) GeV", 10, 0, 3), "q2") 
        
        heff11 = hrec11.Clone()
        heff11.Sumw2()
        heff11.Divide(hgen11.GetPtr())
        heff11.SetMarkerStyle(21)
        heff11.SetMarkerSize(0.5)
        heff11.SetLineColor(ROOT.kRed)
        heff11.Draw("E")
        heff11.GetXaxis().SetLabelSize(0.05)
        heff11.GetYaxis().SetLabelSize(0.05)
        #hgen11.SetLineColor(ROOT.kMagenta)
        #hgen11.Scale(1/hgen11.Integral())
        #hrec11.SetLineColor(ROOT.kBlack)
        #hrec11.Scale(1/hrec11.Integral())
        #hrec11.Draw("same")
        #hgen11.Draw("same")
        #heff11.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==12:
        #c.cd(12)
        c.cd(7)
        """
        hgen12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2")
        hrec12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2") 
        """
        hgen12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.94<=mm_fkpskp && mm_fkpskp<1.98  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2")
        hrec12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.94,1.98) GeV", "MM[1.94,1.98) GeV", 10, 0, 3), "q2") 
        
        
        heff12 = hrec12.Clone()
        heff12.Sumw2()
        heff12.Divide(hgen12.GetPtr())
        heff12.SetMarkerStyle(21)
        heff12.SetMarkerSize(0.5)
        heff12.SetLineColor(ROOT.kRed)
        heff12.Draw("E")
        heff12.GetXaxis().SetLabelSize(0.05)
        heff12.GetYaxis().SetLabelSize(0.05)
        #hgen12.SetLineColor(ROOT.kMagenta)
        #hgen12.Scale(1/hgen12.Integral())
        #hrec12.SetLineColor(ROOT.kBlack)
        #hrec12.Scale(1/hrec12.Integral())
        #hrec12.Draw("same")
        #hgen12.Draw("same")
        #heff12.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==13:
        #c.cd(13)
        c.cd(8)
        """
        hgen13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2")
        hrec13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2") 
        """
        hgen13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.98<=mm_fkpskp && mm_fkpskp<2.02  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2")
        hrec13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.98,2.02) GeV", "MM[1.98,2.02) GeV", 10, 0, 3), "q2") 
        
        heff13 = hrec13.Clone()
        heff13.Sumw2()
        heff13.Divide(hgen13.GetPtr())
        heff13.SetMarkerStyle(21)
        heff13.SetMarkerSize(0.5)
        heff13.SetLineColor(ROOT.kRed)
        heff13.Draw("E")
        heff13.GetXaxis().SetLabelSize(0.05)
        heff13.GetYaxis().SetLabelSize(0.05)
        #hgen13.SetLineColor(ROOT.kMagenta)
        #hgen13.Scale(1/hgen13.Integral())
        #hrec13.SetLineColor(ROOT.kBlack)
        #hrec13.Scale(1/hrec13.Integral())
        #hrec13.Draw("same")
        #hgen13.Draw("same")
        #heff13.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==14:
        #c.cd(14)
        c.cd(9)
        """
        hgen14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2")
        hrec14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2") 
        """
        hgen14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.02<=mm_fkpskp && mm_fkpskp<2.06  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2")
        hrec14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.02,2.06) GeV", "MM[2.02,2.06) GeV", 10, 0, 3), "q2") 
        
        heff14 = hrec14.Clone()
        heff14.Sumw2()
        heff14.Divide(hgen14.GetPtr())
        heff14.SetMarkerStyle(21)
        heff14.SetMarkerSize(0.5)
        heff14.SetLineColor(ROOT.kRed)
        heff14.Draw("E")
        heff14.GetXaxis().SetLabelSize(0.05)
        heff14.GetYaxis().SetLabelSize(0.05)
        #hgen14.SetLineColor(ROOT.kMagenta)
        #hgen14.Scale(1/hgen14.Integral())
        #hrec14.SetLineColor(ROOT.kBlack)
        #hrec14.Scale(1/hrec14.Integral())
        #hrec14.Draw("same")
        #hgen14.Draw("same")
        #heff14.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==15:
        #c.cd(15)
        c.cd(10)
        """
        hgen15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2")
        hrec15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2") 
        """
        hgen15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 ").Filter("2.06<=mm_fkpskp && mm_fkpskp<2.10  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2")
        hrec15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.06,2.10) GeV", "MM[2.06,2.10) GeV", 10, 0, 3), "q2") 
        
        heff15 = hrec15.Clone()
        heff15.Sumw2()
        heff15.Divide(hgen15.GetPtr())
        heff15.SetMarkerStyle(21)
        heff15.SetMarkerSize(0.5)
        heff15.SetLineColor(ROOT.kRed)
        heff15.Draw("E")
        heff15.GetXaxis().SetLabelSize(0.05)
        heff15.GetYaxis().SetLabelSize(0.05)
        #hgen15.SetLineColor(ROOT.kMagenta)
        #hgen15.Scale(1/hgen15.Integral())
        #hrec15.SetLineColor(ROOT.kBlack)
        #hrec15.Scale(1/hrec15.Integral())
        #hrec15.Draw("same")
        #hgen15.Draw("same")
        #heff15.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==16:
        #c.cd(16)
        c.cd(11)
        """
        hgen16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2")
        hrec16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2") 
        """
        hgen16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.10<=mm_fkpskp && mm_fkpskp<2.14  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2")
        hrec16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.10,2.14) GeV", "MM[2.10,2.14) GeV", 10, 0, 3), "q2") 
        
        heff16 = hrec16.Clone()
        heff16.Sumw2()
        heff16.Divide(hgen16.GetPtr())
        heff16.SetMarkerStyle(21)
        heff16.SetMarkerSize(0.5)
        heff16.SetLineColor(ROOT.kRed)
        heff16.Draw("E")
        heff16.GetXaxis().SetLabelSize(0.05)
        heff16.GetYaxis().SetLabelSize(0.05)
        #hgen16.SetLineColor(ROOT.kMagenta)
        #hgen16.Scale(1/hgen16.Integral())
        #hrec16.SetLineColor(ROOT.kBlack)
        #hrec16.Scale(1/hrec16.Integral())
        #hrec16.Draw("same")
        #hgen16.Draw("same")
        #heff16.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==17:
        #c.cd(17)
        c.cd(12)
        """
        hgen17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2")
        hrec17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2") 
        """
        hgen17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.14<=mm_fkpskp && mm_fkpskp<2.18  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2")
        hrec17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.14,2.18) GeV", "MM[2.14,2.18) GeV", 10, 0, 3), "q2") 
        
        heff17 = hrec17.Clone()
        heff17.Sumw2()
        heff17.Divide(hgen17.GetPtr())
        heff17.SetMarkerStyle(21)
        heff17.SetMarkerSize(0.5)
        heff17.SetLineColor(ROOT.kRed)
        heff17.Draw("E")
        heff17.GetXaxis().SetLabelSize(0.05)
        heff17.GetYaxis().SetLabelSize(0.05)
        #hgen17.SetLineColor(ROOT.kMagenta)
        #hgen17.Scale(1/hgen17.Integral())
        #hrec17.SetLineColor(ROOT.kBlack)
        #hrec17.Scale(1/hrec17.Integral())
        #hrec17.Draw("same")
        #hgen17.Draw("same")
        #heff17.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==18:
        #c.cd(18)
        c.cd(13)
        """
        hgen18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2")
        hrec18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2") 
        """
        hgen18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.18<=mm_fkpskp && mm_fkpskp<2.22  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2")
        hrec18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.18,2.22) GeV", "MM[2.18,2.22) GeV", 10, 0, 3), "q2") 
        
        heff18 = hrec18.Clone()
        heff18.Sumw2()
        heff18.Divide(hgen18.GetPtr())
        heff18.SetMarkerStyle(21)
        heff18.SetMarkerSize(0.5)
        heff18.SetLineColor(ROOT.kRed)
        heff18.Draw("E")
        heff18.GetXaxis().SetLabelSize(0.05)
        heff18.GetYaxis().SetLabelSize(0.05)
        #hgen18.SetLineColor(ROOT.kMagenta)
        #hgen18.Scale(1/hgen18.Integral())
        #hrec18.SetLineColor(ROOT.kBlack)
        #hrec18.Scale(1/hrec18.Integral())
        #hrec18.Draw("same")
        #hgen18.Draw("same")
        #heff18.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==19:
        #c.cd(19)
        c.cd(14)
        """
        hgen19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2")
        hrec19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2") 
        """
        hgen19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.22<=mm_fkpskp && mm_fkpskp<2.26  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2")
        hrec19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.22,2.26) GeV", "MM[2.22,2.26) GeV", 10, 0, 3), "q2") 
        
        heff19 = hrec19.Clone()
        heff19.Sumw2()
        heff19.Divide(hgen19.GetPtr())
        heff19.SetMarkerStyle(21)
        heff19.SetMarkerSize(0.5)
        heff19.SetLineColor(ROOT.kRed)
        heff19.Draw("E")
        heff19.GetXaxis().SetLabelSize(0.05)
        heff19.GetYaxis().SetLabelSize(0.05)
        #hgen19.SetLineColor(ROOT.kMagenta)
        #hgen19.Scale(1/hgen19.Integral())
        #hrec19.SetLineColor(ROOT.kBlack)
        #hrec19.Scale(1/hrec19.Integral())
        #hrec19.Draw("same")
        #hgen19.Draw("same")
        #heff19.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==20:
        #c.cd(20)
        c.cd(15)
        """
        hgen20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2")
        hrec20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2") 
        """
        hgen20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.26<=mm_fkpskp && mm_fkpskp<2.30  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 0, 3), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2")
        hrec20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.26,2.30) GeV", "MM[2.26,2.30) GeV", 10, 0, 3), "q2") 
        
        
        heff20 = hrec20.Clone()
        heff20.Sumw2()
        heff20.Divide(hgen20.GetPtr())
        heff20.SetMarkerStyle(21)
        heff20.SetMarkerSize(0.5)
        heff20.SetLineColor(ROOT.kRed)
        heff20.Draw("E")
        heff20.GetXaxis().SetLabelSize(0.05)
        heff20.GetYaxis().SetLabelSize(0.05)
        #hgen20.SetLineColor(ROOT.kMagenta)
        #hgen20.Scale(1/hgen20.Integral())
        #hrec20.SetLineColor(ROOT.kBlack)
        #hrec20.Scale(1/hrec20.Integral())
        #hrec20.Draw("same")
        #hgen20.Draw("same")
        #heff20.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
        """
    elif bn==21:
        c.cd(21)
        hgen21 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.30<=mm_fkpskp && mm_fkpskp<2.34 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.30,2.34)", "MM[2.30,2.34)", 7, 0.0, 0.14), "q2")
        hrec21 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.30<=mm_fkpskp && mm_fkpskp<2.34 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.30,2.34)", "MM[2.30,2.34)", 7, 0.0, 0.14), "q2") 
        hrec21.Sumw2()
        hrec21.Divide(hgen21.GetPtr())
        hrec21.Draw("E")
        #hrec21.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==22:
        c.cd(22)
        hgen22 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.34<=mm_fkpskp && mm_fkpskp<2.38 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.34,2.38)", "MM[2.34,2.38)", 7, 0.0, 0.14), "q2")
        hrec22 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.34<=mm_fkpskp && mm_fkpskp<2.38 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.34,2.38)", "MM[2.34,2.38)", 7, 0.0, 0.14), "q2") 
        hrec22.Sumw2()
        hrec22.Divide(hgen22.GetPtr())
        hrec22.Draw("E")
        #hrec22.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==23:
        c.cd(23)
        hgen23 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.38<=mm_fkpskp && mm_fkpskp<2.42 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.38,2.42)", "MM[2.38,2.42)", 7, 0.0, 0.14), "q2")
        hrec23 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.38<=mm_fkpskp && mm_fkpskp<2.42 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.38,2.42)", "MM[2.38,2.42)", 7, 0.0, 0.14), "q2") 
        hrec23.Sumw2()
        hrec23.Divide(hgen23.GetPtr())
        hrec23.Draw("E")
        #hrec23.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==24:
        c.cd(24)
        hgen24 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.42<=mm_fkpskp && mm_fkpskp<2.46 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.42,2.46)", "MM[2.42,2.46)", 7, 0.0, 0.14), "q2")
        hrec24 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.42<=mm_fkpskp && mm_fkpskp<2.46 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.42,2.46)", "MM[2.42,2.46)", 7, 0.0, 0.14), "q2") 
        hrec24.Sumw2()
        hrec24.Divide(hgen24.GetPtr())
        hrec24.Draw("E")
        #hrec24.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==25:
        c.cd(25)
        hgen25 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/gen_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.46<=mm_fkpskp && mm_fkpskp<2.50 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Histo1D(("MM[2.46,2.50)", "MM[2.46,2.50)", 7, 0.0, 0.14), "q2")
        hrec25 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018out_fde/plot/rec_xi_mc_fall2018out_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.07<=mm_fkpskpkm && mm_fkpskpkm<=1.25&& 2.46<=mm_fkpskp && mm_fkpskp<2.50 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.46,2.50)", "MM[2.46,2.50)", 7, 0.0, 0.14), "q2") 
        hrec25.Sumw2()
        hrec25.Divide(hgen25.GetPtr())
        hrec25.Draw("E")
        #hrec25.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
        """
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# <div id="root_plot_1667137945675"
#      style="width: 2396px; height: 1572px">
# </div>
# <script>
#
# function display_root_plot_1667137945675(Core) {
# ...

# %% [markdown]
# F18IN

# %%
# %jsroot on
c = ROOT.TCanvas("c", "c", 2400,1600)
ROOT.gStyle.SetOptFit(0)
#colms = math.ceil(math.sqrt(h1_eff.GetNbinsX()))
#rows = math.floor(math.sqrt(h1_eff.GetNbinsX()))
#c.Divide(colms, rows, 1E-11, 1E-11)
c.Divide(4, 4, 1E-11, 1E-11)

for i in range(h1_eff.GetNbinsX()):
    
    bn = i+1
    """
    if bn==1:
        c.cd(1)
        hgen1 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.5<=mm_fkpskp && mm_fkpskp<1.54 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.5,1.54)", "MM[1.5,1.54)", 7, 0.0, 0.14), "q2")
        hrec1 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.5<=mm_fkpskp && mm_fkpskp<1.54 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.5,1.54)", "MM[1.5,1.54)", 7, 0.0, 0.14), "q2") 
        heff1 = hrec1.Clone()
        heff1.Sumw2()
        heff1.Divide(hgen1.GetPtr())
        heff1.SetLineColor(ROOT.kRed)
        heff1.Draw("E")
        hgen1.SetLineColor(ROOT.kMagenta)
        #hgen1.Scale(1/hgen1.Integral())
        hrec1.SetLineColor(ROOT.kBlack)
        #hrec1.Scale(1/hrec1.Integral())
        #hrec1.Draw("same")
        #hgen1.Draw("same")
        #heff1.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==2:
        c.cd(2)
        hgen2 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.54<=mm_fkpskp && mm_fkpskp<1.58 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.54,1.58)", "MM[1.54,1.58)", 7, 0.0, 0.14), "q2")
        hrec2 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.54<=mm_fkpskp && mm_fkpskp<1.58 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.54,1.58)", "MM[1.54,1.58)", 7, 0.0, 0.14), "q2") 
        heff2 = hrec2.Clone()
        heff2.Sumw2()
        heff2.Divide(hgen2.GetPtr())
        heff2.SetLineColor(ROOT.kRed)
        heff2.Draw("E")
        hgen2.SetLineColor(ROOT.kMagenta)
        #hgen2.Scale(1/hgen2.Integral())
        hrec2.SetLineColor(ROOT.kBlack)
        #hrec2.Scale(1/hrec2.Integral())
        #hrec2.Draw("same")
        #hgen2.Draw("same")
        #heff2.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==3:
        c.cd(3)
        hgen3 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.58<=mm_fkpskp && mm_fkpskp<1.62 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.58,1.62)", "MM[1.58,1.62)", 7, 0.0, 0.14), "q2")
        hrec3 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.58<=mm_fkpskp && mm_fkpskp<1.62 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.58,1.62)", "MM[1.58,1.62)", 7, 0.0, 0.14), "q2") 
        heff3 = hrec3.Clone()
        heff3.Sumw2()
        heff3.Divide(hgen3.GetPtr())
        heff3.SetLineColor(ROOT.kRed)
        heff3.Draw("E")
        hgen3.SetLineColor(ROOT.kMagenta)
        #hgen3.Scale(1/hgen3.Integral())
        hrec3.SetLineColor(ROOT.kBlack)
        #hrec3.Scale(1/hrec3.Integral())
        #hrec3.Draw("same")
        #hgen3.Draw("same")
        #heff3.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        hrec3.GetXaxis().SetTitleSize(0.05)
        hrec3.GetYaxis().SetTitleSize(0.05)
        hrec3.GetXaxis().SetTitleOffset(0.9)
        hrec3.GetYaxis().SetTitleOffset(0.9)
        hrec3.GetXaxis().SetTitle("Q^{2} [GeV^{2}/c^{4}]")
        hrec3.GetYaxis().SetTitle("#epsilon/Q^{2} bin")
        continue
    elif bn==4:
        c.cd(4)
        hgen4 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.62<=mm_fkpskp && mm_fkpskp<1.66 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.62,1.66)", "MM[1.62,1.66)", 7, 0.0, 0.14), "q2")
        hrec4 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.62<=mm_fkpskp && mm_fkpskp<1.66 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.62,1.66)", "MM[1.62,1.66)", 7, 0.0, 0.14), "q2") 
        heff4 = hrec4.Clone()
        heff4.Sumw2()
        heff4.Divide(hgen4.GetPtr())
        heff4.SetLineColor(ROOT.kRed)
        heff4.Draw("E")
        hgen4.SetLineColor(ROOT.kMagenta)
        #hgen4.Scale(1/hgen4.Integral())
        hrec4.SetLineColor(ROOT.kBlack)
        #hrec4.Scale(1/hrec4.Integral())
        #hrec4.Draw("same")
        #hgen4.Draw("same")
        #heff4.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==5:###################
        c.cd(5)
        hgen5 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.66<=mm_fkpskp && mm_fkpskp<1.70 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.66,1.70)", "MM[1.66,1.70)", 7, 0.0, 0.14), "q2")
        hrec5 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.66<=mm_fkpskp && mm_fkpskp<1.70 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.66,1.70)", "MM[1.66,1.70)", 7, 0.0, 0.14), "q2") 
        heff5 = hrec5.Clone()
        heff5.Sumw2()
        heff5.Divide(hgen5.GetPtr())
        heff5.SetLineColor(ROOT.kRed)
        heff5.Draw("E")
        hgen5.SetLineColor(ROOT.kMagenta)
        #hgen5.Scale(1/hgen5.Integral())
        hrec5.SetLineColor(ROOT.kBlack)
        #hrec5.Scale(1/hrec5.Integral())
        #hrec5.Draw("same")
        #hgen5.Draw("same")
        #heff5.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==6:
    """
    if bn==6:
        c.cd(1)
        #c.cd(6)
        """
        hgen6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.140), "q2")#25, 0.001, 0.4 #7, 0.0, 0.14 # 5, 0.030, 0.130
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2")
        hrec6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2") 
        """
        hgen6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.70<=mm_fkpskp && mm_fkpskp<1.74 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")#25, 0.001, 0.4 #7, 0.0, 0.14 # 5, 0.030, 0.130#10, 1, 4
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2")
        hrec6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.70,1.74) GeV", "MM[1.70,1.74) GeV", 10, 1, 4), "q2") 
        
        heff6 = hrec6.Clone()
        heff6.Sumw2()
        heff6.Divide(hgen6.GetPtr())
        heff6.SetMarkerStyle(21)
        heff6.SetMarkerSize(0.5)
        heff6.SetLineColor(ROOT.kRed)
        heff6.Draw("E")
        heff6.GetXaxis().SetLabelSize(0.05)
        heff6.GetYaxis().SetLabelSize(0.05)
        heff6.GetXaxis().SetTitleSize(0.05)
        heff6.GetYaxis().SetTitleSize(0.05)
        heff6.GetXaxis().SetTitleOffset(0.9)
        heff6.GetYaxis().SetTitleOffset(0.9)
        heff6.GetXaxis().SetTitle("Q^{2} [GeV^{2}/c^{4}]")
        heff6.GetYaxis().SetTitle("#epsilon/Q^{2} bin")
        #hgen6.SetLineColor(ROOT.kMagenta)
        #hgen6.Scale(1/hgen6.Integral())
        #hrec6.SetLineColor(ROOT.kBlack)
        #hrec6.Scale(1/hrec6.Integral())
        #hrec6.Draw("same")
        #hgen6.Draw("same")
        #heff6.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==7:
        #c.cd(7)
        c.cd(2)
        """
        hgen7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2")
        hrec7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2") 
        """
        hgen7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.74<=mm_fkpskp && mm_fkpskp<1.78 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2")
        hrec7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.74,1.78) GeV", "MM[1.74,1.78) GeV", 10, 1, 4), "q2") 
        
        heff7 = hrec7.Clone()
        heff7.Sumw2()
        heff7.Divide(hgen7.GetPtr())
        heff7.SetMarkerStyle(21)
        heff7.SetMarkerSize(0.5)
        heff7.SetLineColor(ROOT.kRed)
        heff7.Draw("E")
        heff7.GetXaxis().SetLabelSize(0.05)
        heff7.GetYaxis().SetLabelSize(0.05)
        #hgen7.SetLineColor(ROOT.kMagenta)
        #hgen7.Scale(1/hgen7.Integral())
        #hrec7.SetLineColor(ROOT.kBlack)
        #hrec7.Scale(1/hrec7.Integral())
        #hrec7.Draw("same")
        #hgen7.Draw("same")
        #heff7.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==8:
        #c.cd(8)
        c.cd(3)
        """
        hgen8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2")
        hrec8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2") 
        """
        hgen8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.78<=mm_fkpskp && mm_fkpskp<1.82  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2")
        hrec8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.78,1.82) GeV", "MM[1.78,1.82) GeV", 10, 1, 4), "q2") 
        
        heff8 = hrec8.Clone()
        heff8.Sumw2()
        heff8.Divide(hgen8.GetPtr())
        heff8.SetMarkerStyle(21)
        heff8.SetMarkerSize(0.5)
        heff8.SetLineColor(ROOT.kRed)
        heff8.Draw("E")
        heff8.GetXaxis().SetLabelSize(0.05)
        heff8.GetYaxis().SetLabelSize(0.05)
        #hgen8.SetLineColor(ROOT.kMagenta)
        #hgen8.Scale(1/hgen8.Integral())
        #hrec8.SetLineColor(ROOT.kBlack)
        #hrec8.Scale(1/hrec8.Integral())
        #hrec8.Draw("same")
        #hgen8.Draw("same")
        #heff8.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==9:
        #c.cd(9)
        c.cd(4)
        """
        hgen9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2")
        hrec9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2") 
        """
        hgen9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.82<=mm_fkpskp && mm_fkpskp<1.86  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2")
        hrec9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.82,1.86) GeV", "MM[1.82,1.86) GeV", 10, 1, 4), "q2") 
        
        heff9 = hrec9.Clone()
        heff9.Sumw2()
        heff9.Divide(hgen9.GetPtr())
        heff9.SetMarkerStyle(21)
        heff9.SetMarkerSize(0.5)
        heff9.SetLineColor(ROOT.kRed)
        heff9.Draw("E")
        heff9.GetXaxis().SetLabelSize(0.05)
        heff9.GetYaxis().SetLabelSize(0.05)
        #hgen9.SetLineColor(ROOT.kMagenta)
        #hgen9.Scale(1/hgen9.Integral())
        #hrec9.SetLineColor(ROOT.kBlack)
        #hrec9.Scale(1/hrec9.Integral())
        #hrec9.Draw("same")
        #hgen9.Draw("same")
        #heff9.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==10:
        #c.cd(10)
        c.cd(5)
        """
        hgen10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2")
        hrec10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2") 
        """
        hgen10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.86<=mm_fkpskp && mm_fkpskp<1.90  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2")
        hrec10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.86,1.90) GeV", "MM[1.86,1.90) GeV", 10, 1, 4), "q2") 
        
        heff10 = hrec10.Clone()
        heff10.Sumw2()
        heff10.Divide(hgen10.GetPtr())
        heff10.SetMarkerStyle(21)
        heff10.SetMarkerSize(0.5)
        heff10.SetLineColor(ROOT.kRed)
        heff10.Draw("E")
        heff10.GetXaxis().SetLabelSize(0.05)
        heff10.GetYaxis().SetLabelSize(0.05)
        #hgen10.SetLineColor(ROOT.kMagenta)
        #hgen10.Scale(1/hgen10.Integral())
        #hrec10.SetLineColor(ROOT.kBlack)
        #hrec10.Scale(1/hrec10.Integral())
        #hrec10.Draw("same")
        #hgen10.Draw("same")
        #heff10.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==11:
        #c.cd(11)
        c.cd(6)
        """
        hgen11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2")
        hrec11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2") 
        """
        hgen11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.90<=mm_fkpskp && mm_fkpskp<1.94  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2")
        hrec11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.90,1.94) GeV", "MM[1.90,1.94) GeV", 10, 1, 4), "q2") 
        
        heff11 = hrec11.Clone()
        heff11.Sumw2()
        heff11.Divide(hgen11.GetPtr())
        heff11.SetMarkerStyle(21)
        heff11.SetMarkerSize(0.5)
        heff11.SetLineColor(ROOT.kRed)
        heff11.Draw("E")
        heff11.GetXaxis().SetLabelSize(0.05)
        heff11.GetYaxis().SetLabelSize(0.05)
        #hgen11.SetLineColor(ROOT.kMagenta)
        #hgen11.Scale(1/hgen11.Integral())
        #hrec11.SetLineColor(ROOT.kBlack)
        #hrec11.Scale(1/hrec11.Integral())
        #hrec11.Draw("same")
        #hgen11.Draw("same")
        #heff11.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==12:
        #c.cd(12)
        c.cd(7)
        """
        hgen12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2")
        hrec12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2") 
        """
        hgen12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.94<=mm_fkpskp && mm_fkpskp<1.98  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2")
        hrec12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.94,1.98) GeV", "MM[1.94,1.98) GeV", 10, 1, 4), "q2") 
        
        
        heff12 = hrec12.Clone()
        heff12.Sumw2()
        heff12.Divide(hgen12.GetPtr())
        heff12.SetMarkerStyle(21)
        heff12.SetMarkerSize(0.5)
        heff12.SetLineColor(ROOT.kRed)
        heff12.Draw("E")
        heff12.GetXaxis().SetLabelSize(0.05)
        heff12.GetYaxis().SetLabelSize(0.05)
        #hgen12.SetLineColor(ROOT.kMagenta)
        #hgen12.Scale(1/hgen12.Integral())
        #hrec12.SetLineColor(ROOT.kBlack)
        #hrec12.Scale(1/hrec12.Integral())
        #hrec12.Draw("same")
        #hgen12.Draw("same")
        #heff12.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==13:
        #c.cd(13)
        c.cd(8)
        """
        hgen13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2")
        hrec13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2") 
        """
        hgen13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.98<=mm_fkpskp && mm_fkpskp<2.02  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2")
        hrec13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.98,2.02) GeV", "MM[1.98,2.02) GeV", 10, 1, 4), "q2") 
        
        heff13 = hrec13.Clone()
        heff13.Sumw2()
        heff13.Divide(hgen13.GetPtr())
        heff13.SetMarkerStyle(21)
        heff13.SetMarkerSize(0.5)
        heff13.SetLineColor(ROOT.kRed)
        heff13.Draw("E")
        heff13.GetXaxis().SetLabelSize(0.05)
        heff13.GetYaxis().SetLabelSize(0.05)
        #hgen13.SetLineColor(ROOT.kMagenta)
        #hgen13.Scale(1/hgen13.Integral())
        #hrec13.SetLineColor(ROOT.kBlack)
        #hrec13.Scale(1/hrec13.Integral())
        #hrec13.Draw("same")
        #hgen13.Draw("same")
        #heff13.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==14:
        #c.cd(14)
        c.cd(9)
        """
        hgen14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2")
        hrec14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2") 
        """
        hgen14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.02<=mm_fkpskp && mm_fkpskp<2.06  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2")
        hrec14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.02,2.06) GeV", "MM[2.02,2.06) GeV", 10, 1, 4), "q2") 
        
        heff14 = hrec14.Clone()
        heff14.Sumw2()
        heff14.Divide(hgen14.GetPtr())
        heff14.SetMarkerStyle(21)
        heff14.SetMarkerSize(0.5)
        heff14.SetLineColor(ROOT.kRed)
        heff14.Draw("E")
        heff14.GetXaxis().SetLabelSize(0.05)
        heff14.GetYaxis().SetLabelSize(0.05)
        #hgen14.SetLineColor(ROOT.kMagenta)
        #hgen14.Scale(1/hgen14.Integral())
        #hrec14.SetLineColor(ROOT.kBlack)
        #hrec14.Scale(1/hrec14.Integral())
        #hrec14.Draw("same")
        #hgen14.Draw("same")
        #heff14.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==15:
        #c.cd(15)
        c.cd(10)
        """
        hgen15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2")
        hrec15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2") 
        """
        hgen15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 ").Filter("2.06<=mm_fkpskp && mm_fkpskp<2.10  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2")
        hrec15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 ").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.06,2.10) GeV", "MM[2.06,2.10) GeV", 10, 1, 4), "q2") 
        
        heff15 = hrec15.Clone()
        heff15.Sumw2()
        heff15.Divide(hgen15.GetPtr())
        heff15.SetMarkerStyle(21)
        heff15.SetMarkerSize(0.5)
        heff15.SetLineColor(ROOT.kRed)
        heff15.Draw("E")
        heff15.GetXaxis().SetLabelSize(0.05)
        heff15.GetYaxis().SetLabelSize(0.05)
        #hgen15.SetLineColor(ROOT.kMagenta)
        #hgen15.Scale(1/hgen15.Integral())
        #hrec15.SetLineColor(ROOT.kBlack)
        #hrec15.Scale(1/hrec15.Integral())
        #hrec15.Draw("same")
        #hgen15.Draw("same")
        #heff15.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==16:
        #c.cd(16)
        c.cd(11)
        """
        hgen16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2")
        hrec16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2") 
        """
        hgen16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.10<=mm_fkpskp && mm_fkpskp<2.14  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2")
        hrec16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.10,2.14) GeV", "MM[2.10,2.14) GeV", 10, 1, 4), "q2") 
        
        heff16 = hrec16.Clone()
        heff16.Sumw2()
        heff16.Divide(hgen16.GetPtr())
        heff16.SetMarkerStyle(21)
        heff16.SetMarkerSize(0.5)
        heff16.SetLineColor(ROOT.kRed)
        heff16.Draw("E")
        heff16.GetXaxis().SetLabelSize(0.05)
        heff16.GetYaxis().SetLabelSize(0.05)
        #hgen16.SetLineColor(ROOT.kMagenta)
        #hgen16.Scale(1/hgen16.Integral())
        #hrec16.SetLineColor(ROOT.kBlack)
        #hrec16.Scale(1/hrec16.Integral())
        #hrec16.Draw("same")
        #hgen16.Draw("same")
        #heff16.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==17:
        #c.cd(17)
        c.cd(12)
        """
        hgen17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2")
        hrec17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2") 
        """
        hgen17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.14<=mm_fkpskp && mm_fkpskp<2.18  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2")
        hrec17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.14,2.18) GeV", "MM[2.14,2.18) GeV", 10, 1, 4), "q2") 
        
        heff17 = hrec17.Clone()
        heff17.Sumw2()
        heff17.Divide(hgen17.GetPtr())
        heff17.SetMarkerStyle(21)
        heff17.SetMarkerSize(0.5)
        heff17.SetLineColor(ROOT.kRed)
        heff17.Draw("E")
        heff17.GetXaxis().SetLabelSize(0.05)
        heff17.GetYaxis().SetLabelSize(0.05)
        #hgen17.SetLineColor(ROOT.kMagenta)
        #hgen17.Scale(1/hgen17.Integral())
        #hrec17.SetLineColor(ROOT.kBlack)
        #hrec17.Scale(1/hrec17.Integral())
        #hrec17.Draw("same")
        #hgen17.Draw("same")
        #heff17.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==18:
        #c.cd(18)
        c.cd(13)
        """
        hgen18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2")
        hrec18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2") 
        """
        hgen18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.18<=mm_fkpskp && mm_fkpskp<2.22  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2")
        hrec18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.18,2.22) GeV", "MM[2.18,2.22) GeV", 10, 1, 4), "q2") 
        
        heff18 = hrec18.Clone()
        heff18.Sumw2()
        heff18.Divide(hgen18.GetPtr())
        heff18.SetMarkerStyle(21)
        heff18.SetMarkerSize(0.5)
        heff18.SetLineColor(ROOT.kRed)
        heff18.Draw("E")
        heff18.GetXaxis().SetLabelSize(0.05)
        heff18.GetYaxis().SetLabelSize(0.05)
        #hgen18.SetLineColor(ROOT.kMagenta)
        #hgen18.Scale(1/hgen18.Integral())
        #hrec18.SetLineColor(ROOT.kBlack)
        #hrec18.Scale(1/hrec18.Integral())
        #hrec18.Draw("same")
        #hgen18.Draw("same")
        #heff18.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==19:
        #c.cd(19)
        c.cd(14)
        """
        hgen19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2")
        hrec19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2") 
        """
        hgen19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.22<=mm_fkpskp && mm_fkpskp<2.26  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2")
        hrec19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.22,2.26) GeV", "MM[2.22,2.26) GeV", 10, 1, 4), "q2") 
        
        heff19 = hrec19.Clone()
        heff19.Sumw2()
        heff19.Divide(hgen19.GetPtr())
        heff19.SetMarkerStyle(21)
        heff19.SetMarkerSize(0.5)
        heff19.SetLineColor(ROOT.kRed)
        heff19.Draw("E")
        heff19.GetXaxis().SetLabelSize(0.05)
        heff19.GetYaxis().SetLabelSize(0.05)
        #hgen19.SetLineColor(ROOT.kMagenta)
        #hgen19.Scale(1/hgen19.Integral())
        #hrec19.SetLineColor(ROOT.kBlack)
        #hrec19.Scale(1/hrec19.Integral())
        #hrec19.Draw("same")
        #hgen19.Draw("same")
        #heff19.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==20:
        #c.cd(20)
        c.cd(15)
        """
        hgen20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2")
        hrec20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2") 
        """
        hgen20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.26<=mm_fkpskp && mm_fkpskp<2.30  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2")
        hrec20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.02<=mm_fkpskpkm && mm_fkpskpkm<=1.28 && 2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.26,2.30) GeV", "MM[2.26,2.30) GeV", 10, 1, 4), "q2") 
        
        
        heff20 = hrec20.Clone()
        heff20.Sumw2()
        heff20.Divide(hgen20.GetPtr())
        heff20.SetMarkerStyle(21)
        heff20.SetMarkerSize(0.5)
        heff20.SetLineColor(ROOT.kRed)
        heff20.Draw("E")
        heff20.GetXaxis().SetLabelSize(0.05)
        heff20.GetYaxis().SetLabelSize(0.05)
        #hgen20.SetLineColor(ROOT.kMagenta)
        #hgen20.Scale(1/hgen20.Integral())
        #hrec20.SetLineColor(ROOT.kBlack)
        #hrec20.Scale(1/hrec20.Integral())
        #hrec20.Draw("same")
        #hgen20.Draw("same")
        #heff20.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
        """
    elif bn==21:
        c.cd(21)
        hgen21 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.30<=mm_fkpskp && mm_fkpskp<2.34 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.30,2.34)", "MM[2.30,2.34)", 7, 0.0, 0.14), "q2")
        hrec21 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.30<=mm_fkpskp && mm_fkpskp<2.34 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.30,2.34)", "MM[2.30,2.34)", 7, 0.0, 0.14), "q2") 
        hrec21.Sumw2()
        hrec21.Divide(hgen21.GetPtr())
        hrec21.Draw("E")
        #hrec21.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==22:
        c.cd(22)
        hgen22 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.34<=mm_fkpskp && mm_fkpskp<2.38 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.34,2.38)", "MM[2.34,2.38)", 7, 0.0, 0.14), "q2")
        hrec22 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.34<=mm_fkpskp && mm_fkpskp<2.38 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.34,2.38)", "MM[2.34,2.38)", 7, 0.0, 0.14), "q2") 
        hrec22.Sumw2()
        hrec22.Divide(hgen22.GetPtr())
        hrec22.Draw("E")
        #hrec22.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==23:
        c.cd(23)
        hgen23 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.38<=mm_fkpskp && mm_fkpskp<2.42 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.38,2.42)", "MM[2.38,2.42)", 7, 0.0, 0.14), "q2")
        hrec23 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.38<=mm_fkpskp && mm_fkpskp<2.42 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.38,2.42)", "MM[2.38,2.42)", 7, 0.0, 0.14), "q2") 
        hrec23.Sumw2()
        hrec23.Divide(hgen23.GetPtr())
        hrec23.Draw("E")
        #hrec23.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==24:
        c.cd(24)
        hgen24 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.42<=mm_fkpskp && mm_fkpskp<2.46 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.42,2.46)", "MM[2.42,2.46)", 7, 0.0, 0.14), "q2")
        hrec24 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.42<=mm_fkpskp && mm_fkpskp<2.46 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.42,2.46)", "MM[2.42,2.46)", 7, 0.0, 0.14), "q2") 
        hrec24.Sumw2()
        hrec24.Divide(hgen24.GetPtr())
        hrec24.Draw("E")
        #hrec24.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==25:
        c.cd(25)
        hgen25 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/gen_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.46<=mm_fkpskp && mm_fkpskp<2.50 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Histo1D(("MM[2.46,2.50)", "MM[2.46,2.50)", 7, 0.0, 0.14), "q2")
        hrec25 = ROOT.RDataFrame("T","../simu_prod/xi_mc_fall2018in_fde/plot/rec_xi_mc_fall2018in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.46<=mm_fkpskp && mm_fkpskp<2.50 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.46,2.50)", "MM[2.46,2.50)", 7, 0.0, 0.14), "q2") 
        hrec25.Sumw2()
        hrec25.Divide(hgen25.GetPtr())
        hrec25.Draw("E")
        #hrec25.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
        """
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# <div id="root_plot_1667138243251"
#      style="width: 2396px; height: 1572px">
# </div>
# <script>
#
# function display_root_plot_1667138243251(Core) {
# ...

# %% [markdown]
# **S19in**

# %%
# %jsroot on
c = ROOT.TCanvas("c", "c", 2400,1600)
#c = ROOT.TCanvas("c", "c", 1024,640)
#c = ROOT.TCanvas("c", "c", 640,1024)
ROOT.gStyle.SetOptFit(0)
#colms = math.ceil(math.sqrt(h1_eff.GetNbinsX()))
#rows = math.floor(math.sqrt(h1_eff.GetNbinsX()))
#c.Divide(colms, rows, 1E-11, 1E-11)
c.Divide(4, 4, 1E-11, 1E-11)

for i in range(h1_eff.GetNbinsX()):
    
    bn = i+1
    """
    if bn==1:
        c.cd(1)
        hgen1 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.5<=mm_fkpskp && mm_fkpskp<1.54 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.5,1.54)", "MM[1.5,1.54)", 7, 0.0, 0.14), "q2")
        hrec1 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.5<=mm_fkpskp && mm_fkpskp<1.54 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.5,1.54)", "MM[1.5,1.54)", 7, 0.0, 0.14), "q2") 
        heff1 = hrec1.Clone()
        heff1.Sumw2()
        heff1.Divide(hgen1.GetPtr())
        heff1.SetLineColor(ROOT.kRed)
        heff1.Draw("E")
        hgen1.SetLineColor(ROOT.kMagenta)
        #hgen1.Scale(1/hgen1.Integral())
        hrec1.SetLineColor(ROOT.kBlack)
        #hrec1.Scale(1/hrec1.Integral())
        #hrec1.Draw("same")
        #hgen1.Draw("same")
        #heff1.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==2:
        c.cd(2)
        hgen2 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.54<=mm_fkpskp && mm_fkpskp<1.58 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.54,1.58)", "MM[1.54,1.58)", 7, 0.0, 0.14), "q2")
        hrec2 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.54<=mm_fkpskp && mm_fkpskp<1.58 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.54,1.58)", "MM[1.54,1.58)", 7, 0.0, 0.14), "q2") 
        heff2 = hrec2.Clone()
        heff2.Sumw2()
        heff2.Divide(hgen2.GetPtr())
        heff2.SetLineColor(ROOT.kRed)
        heff2.Draw("E")
        hgen2.SetLineColor(ROOT.kMagenta)
        #hgen2.Scale(1/hgen2.Integral())
        hrec2.SetLineColor(ROOT.kBlack)
        #hrec2.Scale(1/hrec2.Integral())
        #hrec2.Draw("same")
        #hgen2.Draw("same")
        #heff2.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==3:
        c.cd(3)
        hgen3 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.58<=mm_fkpskp && mm_fkpskp<1.62 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.58,1.62)", "MM[1.58,1.62)", 7, 0.0, 0.14), "q2")
        hrec3 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.58<=mm_fkpskp && mm_fkpskp<1.62 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.58,1.62)", "MM[1.58,1.62)", 7, 0.0, 0.14), "q2") 
        heff3 = hrec3.Clone()
        heff3.Sumw2()
        heff3.Divide(hgen3.GetPtr())
        heff3.SetLineColor(ROOT.kRed)
        heff3.Draw("E")
        hgen3.SetLineColor(ROOT.kMagenta)
        #hgen3.Scale(1/hgen3.Integral())
        hrec3.SetLineColor(ROOT.kBlack)
        #hrec3.Scale(1/hrec3.Integral())
        #hrec3.Draw("same")
        #hgen3.Draw("same")
        #heff3.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        hrec3.GetXaxis().SetTitleSize(0.05)
        hrec3.GetYaxis().SetTitleSize(0.05)
        hrec3.GetXaxis().SetTitleOffset(0.9)
        hrec3.GetYaxis().SetTitleOffset(0.9)
        hrec3.GetXaxis().SetTitle("Q^{2} [GeV^{2}/c^{4}]")
        hrec3.GetYaxis().SetTitle("#epsilon/Q^{2} bin")
        continue
    elif bn==4:
        c.cd(4)
        hgen4 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.62<=mm_fkpskp && mm_fkpskp<1.66 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.62,1.66)", "MM[1.62,1.66)", 7, 0.0, 0.14), "q2")
        hrec4 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.62<=mm_fkpskp && mm_fkpskp<1.66 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.62,1.66)", "MM[1.62,1.66)", 7, 0.0, 0.14), "q2") 
        heff4 = hrec4.Clone()
        heff4.Sumw2()
        heff4.Divide(hgen4.GetPtr())
        heff4.SetLineColor(ROOT.kRed)
        heff4.Draw("E")
        hgen4.SetLineColor(ROOT.kMagenta)
        #hgen4.Scale(1/hgen4.Integral())
        hrec4.SetLineColor(ROOT.kBlack)
        #hrec4.Scale(1/hrec4.Integral())
        #hrec4.Draw("same")
        #hgen4.Draw("same")
        #heff4.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==5:###################
        c.cd(5)
        hgen5 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.66<=mm_fkpskp && mm_fkpskp<1.70 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.66,1.70)", "MM[1.66,1.70)", 7, 0.0, 0.14), "q2")
        hrec5 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.66<=mm_fkpskp && mm_fkpskp<1.70 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.66,1.70)", "MM[1.66,1.70)", 7, 0.0, 0.14), "q2") 
        heff5 = hrec5.Clone()
        heff5.Sumw2()
        heff5.Divide(hgen5.GetPtr())
        heff5.SetLineColor(ROOT.kRed)
        heff5.Draw("E")
        hgen5.SetLineColor(ROOT.kMagenta)
        #hgen5.Scale(1/hgen5.Integral())
        hrec5.SetLineColor(ROOT.kBlack)
        #hrec5.Scale(1/hrec5.Integral())
        #hrec5.Draw("same")
        #hgen5.Draw("same")
        #heff5.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==6:
    """
    if bn==6:
        c.cd(1)
        #c.cd(6)
        """
        hgen6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.140), "q2")#25, 0.001, 0.4 #7, 0.0, 0.14 # 5, 0.030, 0.130
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2")
        hrec6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2") 
        """
        hgen6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.70<=mm_fkpskp && mm_fkpskp<1.74 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")#25, 0.001, 0.4 #7, 0.0, 0.14 # 5, 0.030, 0.130#10, 1, 4
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.70,1.74)", "MM[1.70,1.74)", 7, 0.0, 0.14), "q2")
        hrec6 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.70<=mm_fkpskp && mm_fkpskp<1.74 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.70,1.74) GeV", "MM[1.70,1.74) GeV", 10, 1, 4), "q2") 
        
        heff6 = hrec6.Clone()
        heff6.Sumw2()
        heff6.Divide(hgen6.GetPtr())
        heff6.SetMarkerStyle(21)
        heff6.SetMarkerSize(0.5)
        heff6.SetLineColor(ROOT.kRed)
        heff6.Draw("E")
        
        heff6.GetXaxis().SetLabelSize(0.05)
        heff6.GetYaxis().SetLabelSize(0.05)
        
        heff6.GetXaxis().SetTitleSize(0.05)
        heff6.GetYaxis().SetTitleSize(0.05)
        heff6.GetXaxis().SetTitleOffset(0.9)
        heff6.GetYaxis().SetTitleOffset(0.9)
        heff6.GetXaxis().SetTitle("Q^{2} [GeV^{2}/c^{4}]")
        heff6.GetYaxis().SetTitle("#epsilon/Q^{2} bin")
        #hgen6.SetLineColor(ROOT.kMagenta)
        #hgen6.Scale(1/hgen6.Integral())
        #hrec6.SetLineColor(ROOT.kBlack)
        #hrec6.Scale(1/hrec6.Integral())
        #hrec6.Draw("same")
        #hgen6.Draw("same")
        #heff6.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==7:
        #c.cd(7)
        c.cd(2)
        """
        hgen7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2")
        hrec7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2") 
        """
        hgen7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.74<=mm_fkpskp && mm_fkpskp<1.78 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.74,1.78)", "MM[1.74,1.78)", 7, 0.0, 0.14), "q2")
        hrec7 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.74<=mm_fkpskp && mm_fkpskp<1.78 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.74,1.78) GeV", "MM[1.74,1.78) GeV", 10, 1, 4), "q2") 
        
        heff7 = hrec7.Clone()
        heff7.Sumw2()
        heff7.Divide(hgen7.GetPtr())
        heff7.SetMarkerStyle(21)
        heff7.SetMarkerSize(0.5)
        heff7.SetLineColor(ROOT.kRed)
        heff7.Draw("E")
        
        heff7.GetXaxis().SetLabelSize(0.05)
        heff7.GetYaxis().SetLabelSize(0.05)
        
        #hgen7.SetLineColor(ROOT.kMagenta)
        #hgen7.Scale(1/hgen7.Integral())
        #hrec7.SetLineColor(ROOT.kBlack)
        #hrec7.Scale(1/hrec7.Integral())
        #hrec7.Draw("same")
        #hgen7.Draw("same")
        #heff7.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==8:
        #c.cd(8)
        c.cd(3)
        """
        hgen8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2")
        hrec8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2") 
        """
        hgen8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.78<=mm_fkpskp && mm_fkpskp<1.82  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.78,1.82)", "MM[1.78,1.82)", 7, 0.0, 0.14), "q2")
        hrec8 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.78<=mm_fkpskp && mm_fkpskp<1.82 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.78,1.82) GeV", "MM[1.78,1.82) GeV", 10, 1, 4), "q2") 
        
        heff8 = hrec8.Clone()
        heff8.Sumw2()
        heff8.Divide(hgen8.GetPtr())
        heff8.SetMarkerStyle(21)
        heff8.SetMarkerSize(0.5)
        heff8.SetLineColor(ROOT.kRed)
        heff8.Draw("E")
        heff8.GetXaxis().SetLabelSize(0.05)
        heff8.GetYaxis().SetLabelSize(0.05)
        #hgen8.SetLineColor(ROOT.kMagenta)
        #hgen8.Scale(1/hgen8.Integral())
        #hrec8.SetLineColor(ROOT.kBlack)
        #hrec8.Scale(1/hrec8.Integral())
        #hrec8.Draw("same")
        #hgen8.Draw("same")
        #heff8.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==9:
        #c.cd(9)
        c.cd(4)
        """
        hgen9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2")
        hrec9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2") 
        """
        hgen9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.82<=mm_fkpskp && mm_fkpskp<1.86  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.82,1.86)", "MM[1.82,1.86)", 7, 0.0, 0.14), "q2")
        hrec9 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.82<=mm_fkpskp && mm_fkpskp<1.86 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.82,1.86) GeV", "MM[1.82,1.86) GeV", 10, 1, 4), "q2") 
        
        heff9 = hrec9.Clone()
        heff9.Sumw2()
        heff9.Divide(hgen9.GetPtr())
        heff9.SetMarkerStyle(21)
        heff9.SetMarkerSize(0.5)
        heff9.SetLineColor(ROOT.kRed)
        heff9.Draw("E")
        heff9.GetXaxis().SetLabelSize(0.05)
        heff9.GetYaxis().SetLabelSize(0.05)
        #hgen9.SetLineColor(ROOT.kMagenta)
        #hgen9.Scale(1/hgen9.Integral())
        #hrec9.SetLineColor(ROOT.kBlack)
        #hrec9.Scale(1/hrec9.Integral())
        #hrec9.Draw("same")
        #hgen9.Draw("same")
        #heff9.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==10:
        #c.cd(10)
        c.cd(5)
        """
        hgen10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2")
        hrec10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2") 
        """
        hgen10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.86<=mm_fkpskp && mm_fkpskp<1.90  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.86,1.90)", "MM[1.86,1.90)", 7, 0.0, 0.14), "q2")
        hrec10 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.86<=mm_fkpskp && mm_fkpskp<1.90 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.86,1.90) GeV", "MM[1.86,1.90) GeV", 10, 1, 4), "q2") 
        
        heff10 = hrec10.Clone()
        heff10.Sumw2()
        heff10.Divide(hgen10.GetPtr())
        heff10.SetMarkerStyle(21)
        heff10.SetMarkerSize(0.5)
        heff10.SetLineColor(ROOT.kRed)
        heff10.Draw("E")
        heff10.GetXaxis().SetLabelSize(0.05)
        heff10.GetYaxis().SetLabelSize(0.05)
        #hgen10.SetLineColor(ROOT.kMagenta)
        #hgen10.Scale(1/hgen10.Integral())
        #hrec10.SetLineColor(ROOT.kBlack)
        #hrec10.Scale(1/hrec10.Integral())
        #hrec10.Draw("same")
        #hgen10.Draw("same")
        #heff10.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==11:
        #c.cd(11)
        c.cd(6)
        """
        hgen11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2")
        hrec11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2") 
        """
        hgen11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.90<=mm_fkpskp && mm_fkpskp<1.94  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.90,1.94)", "MM[1.90,1.94)", 7, 0.0, 0.14), "q2")
        hrec11 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.90<=mm_fkpskp && mm_fkpskp<1.94 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.90,1.94) GeV", "MM[1.90,1.94) GeV", 10, 1, 4), "q2") 
        
        heff11 = hrec11.Clone()
        heff11.Sumw2()
        heff11.Divide(hgen11.GetPtr())
        heff11.SetMarkerStyle(21)
        heff11.SetMarkerSize(0.5)
        heff11.SetLineColor(ROOT.kRed)
        heff11.Draw("E")
        heff11.GetXaxis().SetLabelSize(0.05)
        heff11.GetYaxis().SetLabelSize(0.05)
        #hgen11.SetLineColor(ROOT.kMagenta)
        #hgen11.Scale(1/hgen11.Integral())
        #hrec11.SetLineColor(ROOT.kBlack)
        #hrec11.Scale(1/hrec11.Integral())
        #hrec11.Draw("same")
        #hgen11.Draw("same")
        #heff11.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==12:
        #c.cd(12)
        c.cd(7)
        """
        hgen12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2")
        hrec12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2") 
        """
        hgen12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.94<=mm_fkpskp && mm_fkpskp<1.98  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.94,1.98)", "MM[1.94,1.98)", 7, 0.0, 0.14), "q2")
        hrec12 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.94<=mm_fkpskp && mm_fkpskp<1.98 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.94,1.98) GeV", "MM[1.94,1.98) GeV", 10, 1, 4), "q2") 
        
        
        heff12 = hrec12.Clone()
        heff12.Sumw2()
        heff12.Divide(hgen12.GetPtr())
        heff12.SetMarkerStyle(21)
        heff12.SetMarkerSize(0.5)
        heff12.SetLineColor(ROOT.kRed)
        heff12.Draw("E")
        heff12.GetXaxis().SetLabelSize(0.05)
        heff12.GetYaxis().SetLabelSize(0.05)
        #hgen12.SetLineColor(ROOT.kMagenta)
        #hgen12.Scale(1/hgen12.Integral())
        #hrec12.SetLineColor(ROOT.kBlack)
        #hrec12.Scale(1/hrec12.Integral())
        #hrec12.Draw("same")
        #hgen12.Draw("same")
        #heff12.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==13:
        #c.cd(13)
        c.cd(8)
        """
        hgen13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2")
        hrec13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2") 
        """
        hgen13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("1.98<=mm_fkpskp && mm_fkpskp<2.02  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[1.98,2.02)", "MM[1.98,2.02)", 7, 0.0, 0.14), "q2")
        hrec13 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 1.98<=mm_fkpskp && mm_fkpskp<2.02 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[1.98,2.02) GeV", "MM[1.98,2.02) GeV", 10, 1, 4), "q2") 
        
        heff13 = hrec13.Clone()
        heff13.Sumw2()
        heff13.Divide(hgen13.GetPtr())
        heff13.SetMarkerStyle(21)
        heff13.SetMarkerSize(0.5)
        heff13.SetLineColor(ROOT.kRed)
        heff13.Draw("E")
        heff13.GetXaxis().SetLabelSize(0.05)
        heff13.GetYaxis().SetLabelSize(0.05)
        #hgen13.SetLineColor(ROOT.kMagenta)
        #hgen13.Scale(1/hgen13.Integral())
        #hrec13.SetLineColor(ROOT.kBlack)
        #hrec13.Scale(1/hrec13.Integral())
        #hrec13.Draw("same")
        #hgen13.Draw("same")
        #heff13.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==14:
        #c.cd(14)
        c.cd(9)
        """
        hgen14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2")
        hrec14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2") 
        """
        hgen14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.02<=mm_fkpskp && mm_fkpskp<2.06  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.02,2.06)", "MM[2.02,2.06)", 7, 0.0, 0.14), "q2")
        hrec14 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.02<=mm_fkpskp && mm_fkpskp<2.06 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.02,2.06) GeV", "MM[2.02,2.06) GeV", 10, 1, 4), "q2") 
        
        heff14 = hrec14.Clone()
        heff14.Sumw2()
        heff14.Divide(hgen14.GetPtr())
        heff14.SetMarkerStyle(21)
        heff14.SetMarkerSize(0.5)
        heff14.SetLineColor(ROOT.kRed)
        heff14.Draw("E")
        heff14.GetXaxis().SetLabelSize(0.05)
        heff14.GetYaxis().SetLabelSize(0.05)
        #hgen14.SetLineColor(ROOT.kMagenta)
        #hgen14.Scale(1/hgen14.Integral())
        #hrec14.SetLineColor(ROOT.kBlack)
        #hrec14.Scale(1/hrec14.Integral())
        #hrec14.Draw("same")
        #hgen14.Draw("same")
        #heff14.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==15:
        #c.cd(15)
        c.cd(10)
        """
        hgen15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2")
        hrec15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2") 
        """
        hgen15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 ").Filter("2.06<=mm_fkpskp && mm_fkpskp<2.10  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.06,2.10)", "MM[2.06,2.10)", 7, 0.0, 0.14), "q2")
        hrec15 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 ").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.06<=mm_fkpskp && mm_fkpskp<2.10 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.06,2.10) GeV", "MM[2.06,2.10) GeV", 10, 1, 4), "q2") 
        
        heff15 = hrec15.Clone()
        heff15.Sumw2()
        heff15.Divide(hgen15.GetPtr())
        heff15.SetMarkerStyle(21)
        heff15.SetMarkerSize(0.5)
        heff15.SetLineColor(ROOT.kRed)
        heff15.Draw("E")
        heff15.GetXaxis().SetLabelSize(0.05)
        heff15.GetYaxis().SetLabelSize(0.05)
        #hgen15.SetLineColor(ROOT.kMagenta)
        #hgen15.Scale(1/hgen15.Integral())
        #hrec15.SetLineColor(ROOT.kBlack)
        #hrec15.Scale(1/hrec15.Integral())
        #hrec15.Draw("same")
        #hgen15.Draw("same")
        #heff15.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==16:
        #c.cd(16)
        c.cd(11)
        """
        hgen16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2")
        hrec16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2") 
        """
        hgen16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.10<=mm_fkpskp && mm_fkpskp<2.14  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.10,2.14)", "MM[2.10,2.14)", 7, 0.0, 0.14), "q2")
        hrec16 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.10<=mm_fkpskp && mm_fkpskp<2.14 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.10,2.14) GeV", "MM[2.10,2.14) GeV", 10, 1, 4), "q2") 
        
        heff16 = hrec16.Clone()
        heff16.Sumw2()
        heff16.Divide(hgen16.GetPtr())
        heff16.SetMarkerStyle(21)
        heff16.SetMarkerSize(0.5)
        heff16.SetLineColor(ROOT.kRed)
        heff16.Draw("E")
        heff16.GetXaxis().SetLabelSize(0.05)
        heff16.GetYaxis().SetLabelSize(0.05)
        #hgen16.SetLineColor(ROOT.kMagenta)
        #hgen16.Scale(1/hgen16.Integral())
        #hrec16.SetLineColor(ROOT.kBlack)
        #hrec16.Scale(1/hrec16.Integral())
        #hrec16.Draw("same")
        #hgen16.Draw("same")
        #heff16.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==17:
        #c.cd(17)
        c.cd(12)
        """
        hgen17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2")
        hrec17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2") 
        """
        hgen17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.14<=mm_fkpskp && mm_fkpskp<2.18  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.14,2.18)", "MM[2.14,2.18)", 7, 0.0, 0.14), "q2")
        hrec17 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.14<=mm_fkpskp && mm_fkpskp<2.18 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.14,2.18) GeV", "MM[2.14,2.18) GeV", 10, 1, 4), "q2") 
        
        heff17 = hrec17.Clone()
        heff17.Sumw2()
        heff17.Divide(hgen17.GetPtr())
        heff17.SetMarkerStyle(21)
        heff17.SetMarkerSize(0.5)
        heff17.SetLineColor(ROOT.kRed)
        heff17.Draw("E")
        heff17.GetXaxis().SetLabelSize(0.05)
        heff17.GetYaxis().SetLabelSize(0.05)
        #hgen17.SetLineColor(ROOT.kMagenta)
        #hgen17.Scale(1/hgen17.Integral())
        #hrec17.SetLineColor(ROOT.kBlack)
        #hrec17.Scale(1/hrec17.Integral())
        #hrec17.Draw("same")
        #hgen17.Draw("same")
        #heff17.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==18:
        #c.cd(18)
        c.cd(13)
        """
        hgen18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2")
        hrec18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2") 
        """
        hgen18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.18<=mm_fkpskp && mm_fkpskp<2.22  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.18,2.22)", "MM[2.18,2.22)", 7, 0.0, 0.14), "q2")
        hrec18 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.18<=mm_fkpskp && mm_fkpskp<2.22 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.18,2.22) GeV", "MM[2.18,2.22) GeV", 10, 1, 4), "q2") 
        
        heff18 = hrec18.Clone()
        heff18.Sumw2()
        heff18.Divide(hgen18.GetPtr())
        heff18.SetMarkerStyle(21)
        heff18.SetMarkerSize(0.5)
        heff18.SetLineColor(ROOT.kRed)
        heff18.Draw("E")
        heff18.GetXaxis().SetLabelSize(0.05)
        heff18.GetYaxis().SetLabelSize(0.05)
        #hgen18.SetLineColor(ROOT.kMagenta)
        #hgen18.Scale(1/hgen18.Integral())
        #hrec18.SetLineColor(ROOT.kBlack)
        #hrec18.Scale(1/hrec18.Integral())
        #hrec18.Draw("same")
        #hgen18.Draw("same")
        #heff18.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==19:
        #c.cd(19)
        c.cd(14)
        """
        hgen19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2")
        hrec19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2") 
        """
        hgen19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.22<=mm_fkpskp && mm_fkpskp<2.26  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.22,2.26)", "MM[2.22,2.26)", 7, 0.0, 0.14), "q2")
        hrec19 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.22<=mm_fkpskp && mm_fkpskp<2.26 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.22,2.26) GeV", "MM[2.22,2.26) GeV", 10, 1, 4), "q2") 
        
        heff19 = hrec19.Clone()
        heff19.Sumw2()
        heff19.Divide(hgen19.GetPtr())
        heff19.SetMarkerStyle(21)
        heff19.SetMarkerSize(0.5)
        heff19.SetLineColor(ROOT.kRed)
        heff19.Draw("E")
        heff19.GetXaxis().SetLabelSize(0.05)
        heff19.GetYaxis().SetLabelSize(0.05)
        #hgen19.SetLineColor(ROOT.kMagenta)
        #hgen19.Scale(1/hgen19.Integral())
        #hrec19.SetLineColor(ROOT.kBlack)
        #hrec19.Scale(1/hrec19.Integral())
        #hrec19.Draw("same")
        #hgen19.Draw("same")
        #heff19.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==20:
        #c.cd(20)
        c.cd(15)
        """
        hgen20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2")
        hrec20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2") 
        """
        hgen20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3").Filter("2.26<=mm_fkpskp && mm_fkpskp<2.30  && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 10, 1, 4), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.26,2.30)", "MM[2.26,2.30)", 7, 0.0, 0.14), "q2")
        hrec20 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.05<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.26<=mm_fkpskp && mm_fkpskp<2.30 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.26,2.30) GeV", "MM[2.26,2.30) GeV", 10, 1, 4), "q2") 
        
        
        heff20 = hrec20.Clone()
        heff20.Sumw2()
        heff20.Divide(hgen20.GetPtr())
        heff20.SetMarkerStyle(21)
        heff20.SetMarkerSize(0.5)
        heff20.SetLineColor(ROOT.kRed)
        heff20.Draw("E")
        heff20.GetXaxis().SetLabelSize(0.05)
        heff20.GetYaxis().SetLabelSize(0.05)
        #hgen20.SetLineColor(ROOT.kMagenta)
        #hgen20.Scale(1/hgen20.Integral())
        #hrec20.SetLineColor(ROOT.kBlack)
        #hrec20.Scale(1/hrec20.Integral())
        #hrec20.Draw("same")
        #hgen20.Draw("same")
        #heff20.Fit("pol1", "EMS"," ", 0.03292, 0.1167)
        continue
        """
    elif bn==21:
        c.cd(21)
        hgen21 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.30<=mm_fkpskp && mm_fkpskp<2.34 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.30,2.34)", "MM[2.30,2.34)", 7, 0.0, 0.14), "q2")
        hrec21 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.30<=mm_fkpskp && mm_fkpskp<2.34 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.30,2.34)", "MM[2.30,2.34)", 7, 0.0, 0.14), "q2") 
        hrec21.Sumw2()
        hrec21.Divide(hgen21.GetPtr())
        hrec21.Draw("E")
        #hrec21.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==22:
        c.cd(22)
        hgen22 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.34<=mm_fkpskp && mm_fkpskp<2.38 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.34,2.38)", "MM[2.34,2.38)", 7, 0.0, 0.14), "q2")
        hrec22 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.34<=mm_fkpskp && mm_fkpskp<2.38 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.34,2.38)", "MM[2.34,2.38)", 7, 0.0, 0.14), "q2") 
        hrec22.Sumw2()
        hrec22.Divide(hgen22.GetPtr())
        hrec22.Draw("E")
        #hrec22.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==23:
        c.cd(23)
        hgen23 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.38<=mm_fkpskp && mm_fkpskp<2.42 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.38,2.42)", "MM[2.38,2.42)", 7, 0.0, 0.14), "q2")
        hrec23 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.38<=mm_fkpskp && mm_fkpskp<2.42 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.38,2.42)", "MM[2.38,2.42)", 7, 0.0, 0.14), "q2") 
        hrec23.Sumw2()
        hrec23.Divide(hgen23.GetPtr())
        hrec23.Draw("E")
        #hrec23.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==24:
        c.cd(24)
        hgen24 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.42<=mm_fkpskp && mm_fkpskp<2.46 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.42,2.46)", "MM[2.42,2.46)", 7, 0.0, 0.14), "q2")
        hrec24 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.42<=mm_fkpskp && mm_fkpskp<2.46 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.42,2.46)", "MM[2.42,2.46)", 7, 0.0, 0.14), "q2") 
        hrec24.Sumw2()
        hrec24.Divide(hgen24.GetPtr())
        hrec24.Draw("E")
        #hrec24.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
    elif bn==25:
        c.cd(25)
        hgen25 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/gen_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("2.46<=mm_fkpskp && mm_fkpskp<2.50 && e_theta <=35 && 5<=e_theta").Histo1D(("hgen_q2", "hgen_q2", 7, 0.0, 0.14), "q2")
        #hrec = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Histo1D(("MM[2.46,2.50)", "MM[2.46,2.50)", 7, 0.0, 0.14), "q2")
        hrec25 = ROOT.RDataFrame("T","../simu_prod/xi_mc_spring2019in_fde/plot/rec_xi_mc_spring2019in_fde.root").Filter("1.7<=mm_fkpskp && mm_fkpskp<=2.3 && q2>=0.03292 && q2<=0.1287").Filter("1.00<=mm_fkpskpkm && mm_fkpskpkm<=1.29 && 2.46<=mm_fkpskp && mm_fkpskp<2.50 && e_theta <=35 && 5<=e_theta").Histo1D(("MM[2.46,2.50)", "MM[2.46,2.50)", 7, 0.0, 0.14), "q2") 
        hrec25.Sumw2()
        hrec25.Divide(hgen25.GetPtr())
        hrec25.Draw("E")
        #hrec25.Fit("pol0", "EMS"," ", 0.03292, 0.1167)
        continue
        """
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# <div id="root_plot_1667135098201"
#      style="width: 2396px; height: 1572px">
# </div>
# <script>
#
# function display_root_plot_1667135098201(Core) {
# ...
